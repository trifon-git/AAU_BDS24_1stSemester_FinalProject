# %%
import os

# Define the output directory
OUTPUT_DIR = "job_listings"

# Create the directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime, timedelta
import os



def fetch_job_listings(keyword, mindate, maxdate, page_limit=1):
    base_url = "https://www.jobindex.dk/jobsoegning.json?jobage=archive&subid=1&subid=2&subid=3&subid=4&subid=6&subid=7&subid=93"
    job_listings = []

    for page in range(1, page_limit + 1):
        params = {
            "q": keyword,
            "mindate": mindate,
            "maxdate": maxdate,
            "page": page
        }
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            html_content = data.get('result_list_box_html', '')
            soup = BeautifulSoup(html_content, 'html.parser')

            # Find all job ads
            job_ads = soup.find_all('div', class_='jobsearch-result')
            
            # Stop if no job postings are found
            if not job_ads:
                print(f"No job postings found on page {page}. Stopping early.")
                break

            for job_ad in job_ads:
                # Extract title and URL
                title = job_ad.find('div', class_='jobad-element-menu-share')['data-share-title']
                url = job_ad.find('div', class_='jobad-element-menu-share')['data-share-url']
                job_location = job_ad.find('span', class_='jix_robotjob--area')

                # Extract the publication date
                published_tag = job_ad.find('time')
                published_date = published_tag['datetime'] if published_tag else 'Unknown'

                # Fetch additional details from the job URL
                details_response = requests.get(url)
                if details_response.status_code == 200:
                    details_soup = BeautifulSoup(details_response.content, 'html.parser')

                    # Locate the div containing job description
                    paid_job_inner = details_soup.find('div', class_='PaidJob-inner')
                    if paid_job_inner:
                        paragraphs = paid_job_inner.find_all('p')
                        job_details = " ".join(paragraph.get_text(strip=True) for paragraph in paragraphs)
                    else:
                        job_details = "Relevant details not found in the PaidJob-inner section."

                    # Locate the button and extract its href
                    button = details_soup.find('a', class_='btn btn-sm btn-block btn-primary d-md-none mt-2 seejobmobil')
                    if button and 'href' in button.attrs:
                        button_href = button['href']  # Extract the URL from the href attribute
                    else:
                        button_href = "No URL found"

                    # Append all data to the list
                    job_listings.append({
                        "Title": title,
                        "URL": url,
                        "Area": job_location.get_text(strip=True) if job_location else 'Unknown',
                        "Published": published_date,
                        "Description": job_details,
                        "Job Link": button_href
                    })

    return job_listings



def update_json_if_new(output_file, new_data, update_threshold=5):
    # Load existing data safely
    try:
        with open(output_file, 'r') as f:
            existing_data = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        print(f"Error loading JSON file: {output_file}. Starting with an empty dataset.")
        existing_data = []

    # Combine data and remove duplicates
    combined_data = pd.DataFrame(existing_data + new_data).drop_duplicates(subset=["Title", "URL"]).to_dict(orient="records")

    # Identify new rows
    new_rows = [row for row in new_data if row not in existing_data]

    # Update only if new rows exceed the threshold
    if len(new_rows) >= update_threshold:
        try:
            with open(output_file, 'w') as f:
                json.dump(combined_data, f, indent=4)
            print(f"JSON updated with {len(new_rows)} new rows.")
        except Exception as e:
            print(f"Error writing to JSON file: {output_file}. Error: {e}")
    else:
        print(f"Only {len(new_rows)} new rows found. Waiting for {update_threshold - len(new_rows)} more.")






def generate_daily_date_ranges(start_date, end_date, last_processed=None):
    """Generate a list of (mindate, maxdate) pairs for each day, skipping already processed dates."""
    date_ranges = []
    current_date = start_date

    # If a last_processed date exists, start from the next day
    if last_processed:
        current_date = datetime.strptime(last_processed, '%Y%m%d') + timedelta(days=1)

    # Generate daily date ranges where both mindate and maxdate are the same
    while current_date < end_date:
        date_ranges.append((current_date.strftime('%Y%m%d'), current_date.strftime('%Y%m%d')))
        current_date += timedelta(days=1)

    return date_ranges





def scrape_date_range(date_range, keyword, output_file_base, page_limit=1):
    mindate, maxdate = date_range
    print(f"Scraping data from {mindate} to {maxdate}...")
    try:
        new_data = fetch_job_listings(keyword, mindate, maxdate, page_limit)
        if new_data:
            # Construct the full file path
            output_file = os.path.join(OUTPUT_DIR, f"{output_file_base}_{mindate}.json")
            
            # Save data to the JSON file
            with open(output_file, 'w') as f:
                json.dump(new_data, f, indent=4)
            print(f"Data for {mindate} saved to {output_file}.")
        else:
            print(f"No data found for {mindate}.")
    except Exception as e:
        print(f"Error scraping date range {mindate} to {maxdate}: {e}. Skipping.")

# %%
import json

def save_progress(last_processed_date):
    """Save the last processed date to a file."""
    with open('progress.json', 'w') as f:
        json.dump({'last_processed': last_processed_date}, f)
    print(f"Progress saved: {last_processed_date}")

# %%
def load_progress():
    """Load the last processed date from the progress file."""
    try:
        with open('progress.json', 'r') as f:
            progress = json.load(f)
            return progress.get('last_processed', None)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Progress file is missing or corrupted. Resetting progress.")
        save_progress(None)  # Reset progress
        return None

# %%
if __name__ == "__main__":
    try:
        # Configuration
        output_file_base = "job_listings"  # Base name for output files
        keyword = ""
        start_date = datetime(2016, 1, 1)
        end_date = datetime(2024, 11, 22)
        page_limit = 1000

        # Generate date ranges and load progress
        date_ranges = generate_daily_date_ranges(start_date, end_date)
        last_processed = load_progress()
        start_index = next((i for i, date_range in enumerate(date_ranges) if date_range[0] == last_processed), 0)

        # Parallel scraping
        with ThreadPoolExecutor(max_workers=40) as executor:
            futures = [executor.submit(scrape_date_range, date_range, keyword, output_file_base, page_limit)
                       for date_range in date_ranges[start_index:]]
            for future in futures:
                try:
                    future.result()
                except Exception as e:
                    print(f"Error in parallel scraping task: {e}. Skipping.")

        print("All scraping tasks completed.")
    except Exception as e:
        print(f"Critical error in the scraping pipeline: {e}")
# Out:
# Scraping data from 20160101 to 20160101...
# Scraping data from 20160102 to 20160102...
# Scraping data from 20160103 to 20160103...
# Scraping data from 20160104 to 20160104...
# Scraping data from 20160105 to 20160105...
# Scraping data from 20160106 to 20160106...
# Scraping data from 20160107 to 20160107...
# Scraping data from 20160108 to 20160108...
# Scraping data from 20160109 to 20160109...
# Scraping data from 20160110 to 20160110...
# Scraping data from 20160111 to 20160111...
# Scraping data from 20160112 to 20160112...
# Scraping data from 20160113 to 20160113...
# Scraping data from 20160114 to 20160114...
# Scraping data from 20160115 to 20160115...
# Scraping data from 20160116 to 20160116...
# Scraping data from 20160117 to 20160117...
# Scraping data from 20160118 to 20160118...
# Scraping data from 20160119 to 20160119...
# Scraping data from 20160120 to 20160120...
# Scraping data from 20160121 to 20160121...
# Scraping data from 20160122 to 20160122...
# Scraping data from 20160123 to 20160123...
# Scraping data from 20160124 to 20160124...
# Scraping data from 20160125 to 20160125...
# Scraping data from 20160126 to 20160126...
# Scraping data from 20160127 to 20160127...
# Scraping data from 20160128 to 20160128...
# Scraping data from 20160129 to 20160129...
# Scraping data from 20160130 to 20160130...
# Scraping data from 20160131 to 20160131...
# Scraping data from 20160201 to 20160201...
# Scraping data from 20160202 to 20160202...
# Scraping data from 20160203 to 20160203...
# Scraping data from 20160204 to 20160204...
# Scraping data from 20160205 to 20160205...
# Scraping data from 20160206 to 20160206...
# Scraping data from 20160207 to 20160207...
# Scraping data from 20160208 to 20160208...
# Scraping data from 20160209 to 20160209...
# No job postings found on page 2. Stopping early.
# Data for 20160131 saved to job_listings\job_listings_20160131.json.
# Scraping data from 20160210 to 20160210...
# No job postings found on page 2. Stopping early.
# Data for 20160102 saved to job_listings\job_listings_20160102.json.
# Scraping data from 20160211 to 20160211...
# No job postings found on page 2. Stopping early.
# Data for 20160117 saved to job_listings\job_listings_20160117.json.
# Scraping data from 20160212 to 20160212...
# No job postings found on page 2. Stopping early.
# Data for 20160103 saved to job_listings\job_listings_20160103.json.
# Scraping data from 20160213 to 20160213...
# No job postings found on page 2. Stopping early.
# Data for 20160207 saved to job_listings\job_listings_20160207.json.
# Scraping data from 20160214 to 20160214...
# No job postings found on page 2. Stopping early.
# Data for 20160110 saved to job_listings\job_listings_20160110.json.
# Scraping data from 20160215 to 20160215...
# No job postings found on page 2. Stopping early.
# Data for 20160123 saved to job_listings\job_listings_20160123.json.
# Scraping data from 20160216 to 20160216...
# No job postings found on page 2. Stopping early.
# Data for 20160213 saved to job_listings\job_listings_20160213.json.
# Scraping data from 20160217 to 20160217...
# No job postings found on page 2. Stopping early.
# Data for 20160130 saved to job_listings\job_listings_20160130.json.
# Scraping data from 20160218 to 20160218...
# No job postings found on page 2. Stopping early.
# Data for 20160214 saved to job_listings\job_listings_20160214.json.
# Scraping data from 20160219 to 20160219...
# No job postings found on page 2. Stopping early.
# Data for 20160101 saved to job_listings\job_listings_20160101.json.
# Scraping data from 20160220 to 20160220...
# No job postings found on page 2. Stopping early.
# Data for 20160109 saved to job_listings\job_listings_20160109.json.
# Scraping data from 20160221 to 20160221...
# No job postings found on page 3. Stopping early.
# Data for 20160206 saved to job_listings\job_listings_20160206.json.
# Scraping data from 20160222 to 20160222...
# No job postings found on page 2. Stopping early.
# Data for 20160221 saved to job_listings\job_listings_20160221.json.
# Scraping data from 20160223 to 20160223...
# No job postings found on page 3. Stopping early.
# Data for 20160124 saved to job_listings\job_listings_20160124.json.
# Scraping data from 20160224 to 20160224...
# No job postings found on page 2. Stopping early.
# Data for 20160220 saved to job_listings\job_listings_20160220.json.
# Scraping data from 20160225 to 20160225...
# No job postings found on page 3. Stopping early.
# Data for 20160116 saved to job_listings\job_listings_20160116.json.
# Scraping data from 20160226 to 20160226...
# No job postings found on page 4. Stopping early.
# Data for 20160107 saved to job_listings\job_listings_20160107.json.
# Scraping data from 20160227 to 20160227...
# No job postings found on page 4. Stopping early.
# Data for 20160119 saved to job_listings\job_listings_20160119.json.
# Scraping data from 20160228 to 20160228...
# No job postings found on page 4. Stopping early.
# Data for 20160129 saved to job_listings\job_listings_20160129.json.
# Scraping data from 20160229 to 20160229...
# No job postings found on page 4. Stopping early.
# Data for 20160127 saved to job_listings\job_listings_20160127.json.
# Scraping data from 20160301 to 20160301...
# No job postings found on page 4. Stopping early.
# Data for 20160104 saved to job_listings\job_listings_20160104.json.
# Scraping data from 20160302 to 20160302...
# No job postings found on page 4. Stopping early.
# Data for 20160126 saved to job_listings\job_listings_20160126.json.
# Scraping data from 20160303 to 20160303...
# No job postings found on page 4. Stopping early.
# Data for 20160210 saved to job_listings\job_listings_20160210.json.
# Scraping data from 20160304 to 20160304...
# No job postings found on page 5. Stopping early.
# Data for 20160106 saved to job_listings\job_listings_20160106.json.
# Scraping data from 20160305 to 20160305...
# No job postings found on page 5. Stopping early.
# Data for 20160204 saved to job_listings\job_listings_20160204.json.
# Scraping data from 20160306 to 20160306...
# No job postings found on page 5. Stopping early.
# Data for 20160125 saved to job_listings\job_listings_20160125.json.
# Scraping data from 20160307 to 20160307...
# No job postings found on page 2. Stopping early.
# Data for 20160227 saved to job_listings\job_listings_20160227.json.
# Scraping data from 20160308 to 20160308...
# No job postings found on page 5. Stopping early.
# Data for 20160121 saved to job_listings\job_listings_20160121.json.
# Scraping data from 20160309 to 20160309...
# No job postings found on page 5. Stopping early.
# Data for 20160115 saved to job_listings\job_listings_20160115.json.
# Scraping data from 20160310 to 20160310...
# No job postings found on page 5. Stopping early.
# Data for 20160205 saved to job_listings\job_listings_20160205.json.
# Scraping data from 20160311 to 20160311...
# No job postings found on page 5. Stopping early.
# Data for 20160212 saved to job_listings\job_listings_20160212.json.
# Scraping data from 20160312 to 20160312...
# No job postings found on page 5. Stopping early.
# Data for 20160112 saved to job_listings\job_listings_20160112.json.
# Scraping data from 20160313 to 20160313...
# No job postings found on page 2. Stopping early.
# Data for 20160306 saved to job_listings\job_listings_20160306.json.
# Scraping data from 20160314 to 20160314...
# No job postings found on page 5. Stopping early.
# Data for 20160113 saved to job_listings\job_listings_20160113.json.
# Scraping data from 20160315 to 20160315...
# No job postings found on page 5. Stopping early.
# Data for 20160203 saved to job_listings\job_listings_20160203.json.
# Scraping data from 20160316 to 20160316...
# No job postings found on page 5. Stopping early.
# Data for 20160208 saved to job_listings\job_listings_20160208.json.
# Scraping data from 20160317 to 20160317...
# No job postings found on page 5. Stopping early.
# Data for 20160111 saved to job_listings\job_listings_20160111.json.
# Scraping data from 20160318 to 20160318...
# No job postings found on page 2. Stopping early.
# Data for 20160228 saved to job_listings\job_listings_20160228.json.
# Scraping data from 20160319 to 20160319...
# No job postings found on page 5. Stopping early.
# Data for 20160201 saved to job_listings\job_listings_20160201.json.
# Scraping data from 20160320 to 20160320...
# No job postings found on page 5. Stopping early.
# Data for 20160120 saved to job_listings\job_listings_20160120.json.
# Scraping data from 20160321 to 20160321...
# No job postings found on page 2. Stopping early.
# Data for 20160305 saved to job_listings\job_listings_20160305.json.
# Scraping data from 20160322 to 20160322...
# No job postings found on page 5. Stopping early.
# Data for 20160118 saved to job_listings\job_listings_20160118.json.
# Scraping data from 20160323 to 20160323...
# No job postings found on page 5. Stopping early.
# Data for 20160209 saved to job_listings\job_listings_20160209.json.
# Scraping data from 20160324 to 20160324...
# No job postings found on page 2. Stopping early.
# Data for 20160313 saved to job_listings\job_listings_20160313.json.
# Scraping data from 20160325 to 20160325...
# No job postings found on page 5. Stopping early.
# Data for 20160202 saved to job_listings\job_listings_20160202.json.
# Scraping data from 20160326 to 20160326...
# No job postings found on page 5. Stopping early.
# Data for 20160211 saved to job_listings\job_listings_20160211.json.
# Scraping data from 20160327 to 20160327...
# No job postings found on page 5. Stopping early.
# Data for 20160215 saved to job_listings\job_listings_20160215.json.
# Scraping data from 20160328 to 20160328...
# No job postings found on page 2. Stopping early.
# Data for 20160320 saved to job_listings\job_listings_20160320.json.
# Scraping data from 20160329 to 20160329...
# No job postings found on page 2. Stopping early.
# Data for 20160312 saved to job_listings\job_listings_20160312.json.
# Scraping data from 20160330 to 20160330...
# No job postings found on page 5. Stopping early.
# Data for 20160219 saved to job_listings\job_listings_20160219.json.
# Scraping data from 20160331 to 20160331...
# No job postings found on page 6. Stopping early.
# Data for 20160128 saved to job_listings\job_listings_20160128.json.
# Scraping data from 20160401 to 20160401...
# No job postings found on page 2. Stopping early.
# Data for 20160326 saved to job_listings\job_listings_20160326.json.
# Scraping data from 20160402 to 20160402...
# No job postings found on page 5. Stopping early.
# Data for 20160217 saved to job_listings\job_listings_20160217.json.
# Scraping data from 20160403 to 20160403...
# No job postings found on page 2. Stopping early.
# Data for 20160319 saved to job_listings\job_listings_20160319.json.
# Scraping data from 20160404 to 20160404...
# No job postings found on page 2. Stopping early.
# Data for 20160325 saved to job_listings\job_listings_20160325.json.
# Scraping data from 20160405 to 20160405...
# No job postings found on page 6. Stopping early.
# Data for 20160114 saved to job_listings\job_listings_20160114.json.
# Scraping data from 20160406 to 20160406...
# No job postings found on page 5. Stopping early.
# Data for 20160216 saved to job_listings\job_listings_20160216.json.
# Scraping data from 20160407 to 20160407...
# No job postings found on page 2. Stopping early.
# Data for 20160327 saved to job_listings\job_listings_20160327.json.
# Scraping data from 20160408 to 20160408...
# No job postings found on page 6. Stopping early.
# Data for 20160108 saved to job_listings\job_listings_20160108.json.
# Scraping data from 20160409 to 20160409...
# No job postings found on page 2. Stopping early.
# Data for 20160328 saved to job_listings\job_listings_20160328.json.
# Scraping data from 20160410 to 20160410...
# No job postings found on page 5. Stopping early.
# Data for 20160218 saved to job_listings\job_listings_20160218.json.
# Scraping data from 20160411 to 20160411...
# No job postings found on page 5. Stopping early.
# Data for 20160223 saved to job_listings\job_listings_20160223.json.
# Scraping data from 20160412 to 20160412...
# No job postings found on page 2. Stopping early.
# Data for 20160402 saved to job_listings\job_listings_20160402.json.
# Scraping data from 20160413 to 20160413...
# No job postings found on page 5. Stopping early.
# Data for 20160225 saved to job_listings\job_listings_20160225.json.
# Scraping data from 20160414 to 20160414...
# No job postings found on page 2. Stopping early.
# Data for 20160403 saved to job_listings\job_listings_20160403.json.
# Scraping data from 20160415 to 20160415...
# No job postings found on page 2. Stopping early.
# Data for 20160324 saved to job_listings\job_listings_20160324.json.
# Scraping data from 20160416 to 20160416...
# No job postings found on page 2. Stopping early.
# Data for 20160410 saved to job_listings\job_listings_20160410.json.
# Scraping data from 20160417 to 20160417...
# No job postings found on page 6. Stopping early.
# Data for 20160105 saved to job_listings\job_listings_20160105.json.
# Scraping data from 20160418 to 20160418...
# No job postings found on page 5. Stopping early.
# Data for 20160224 saved to job_listings\job_listings_20160224.json.
# Scraping data from 20160419 to 20160419...
# No job postings found on page 1. Stopping early.
# No data found for 20160417.
# Scraping data from 20160420 to 20160420...
# No job postings found on page 2. Stopping early.
# Data for 20160409 saved to job_listings\job_listings_20160409.json.
# Scraping data from 20160421 to 20160421...
# No job postings found on page 6. Stopping early.
# Data for 20160222 saved to job_listings\job_listings_20160222.json.
# Scraping data from 20160422 to 20160422...
# No job postings found on page 2. Stopping early.
# Data for 20160416 saved to job_listings\job_listings_20160416.json.
# Scraping data from 20160423 to 20160423...
# No job postings found on page 6. Stopping early.
# Data for 20160226 saved to job_listings\job_listings_20160226.json.
# Scraping data from 20160424 to 20160424...
# No job postings found on page 2. Stopping early.
# Data for 20160423 saved to job_listings\job_listings_20160423.json.
# Scraping data from 20160425 to 20160425...
# No job postings found on page 2. Stopping early.
# Data for 20160424 saved to job_listings\job_listings_20160424.json.
# Scraping data from 20160426 to 20160426...
# No job postings found on page 5. Stopping early.
# Data for 20160301 saved to job_listings\job_listings_20160301.json.
# Scraping data from 20160427 to 20160427...
# No job postings found on page 5. Stopping early.
# Data for 20160303 saved to job_listings\job_listings_20160303.json.
# Scraping data from 20160428 to 20160428...
# No job postings found on page 2. Stopping early.
# Data for 20160422 saved to job_listings\job_listings_20160422.json.
# Scraping data from 20160429 to 20160429...
# No job postings found on page 4. Stopping early.
# Data for 20160323 saved to job_listings\job_listings_20160323.json.
# Scraping data from 20160430 to 20160430...
# No job postings found on page 4. Stopping early.
# Data for 20160309 saved to job_listings\job_listings_20160309.json.
# Scraping data from 20160501 to 20160501...
# No job postings found on page 5. Stopping early.
# Data for 20160302 saved to job_listings\job_listings_20160302.json.
# Scraping data from 20160502 to 20160502...
# No job postings found on page 4. Stopping early.
# Data for 20160315 saved to job_listings\job_listings_20160315.json.
# Scraping data from 20160503 to 20160503...
# No job postings found on page 5. Stopping early.
# Data for 20160304 saved to job_listings\job_listings_20160304.json.
# Scraping data from 20160504 to 20160504...
# No job postings found on page 5. Stopping early.
# Data for 20160229 saved to job_listings\job_listings_20160229.json.
# Scraping data from 20160505 to 20160505...
# No job postings found on page 2. Stopping early.
# Data for 20160501 saved to job_listings\job_listings_20160501.json.
# Scraping data from 20160506 to 20160506...
# No job postings found on page 4. Stopping early.
# Data for 20160413 saved to job_listings\job_listings_20160413.json.
# Scraping data from 20160507 to 20160507...
# No job postings found on page 2. Stopping early.
# Data for 20160430 saved to job_listings\job_listings_20160430.json.
# Scraping data from 20160508 to 20160508...
# No job postings found on page 5. Stopping early.
# Data for 20160308 saved to job_listings\job_listings_20160308.json.
# Scraping data from 20160509 to 20160509...
# No job postings found on page 5. Stopping early.
# Data for 20160322 saved to job_listings\job_listings_20160322.json.
# Scraping data from 20160510 to 20160510...
# No job postings found on page 4. Stopping early.
# Data for 20160329 saved to job_listings\job_listings_20160329.json.
# Scraping data from 20160511 to 20160511...
# No job postings found on page 2. Stopping early.
# Data for 20160508 saved to job_listings\job_listings_20160508.json.
# Scraping data from 20160512 to 20160512...
# No job postings found on page 2. Stopping early.
# Data for 20160507 saved to job_listings\job_listings_20160507.json.
# Scraping data from 20160513 to 20160513...
# No job postings found on page 5. Stopping early.
# Data for 20160331 saved to job_listings\job_listings_20160331.json.
# Scraping data from 20160514 to 20160514...
# No job postings found on page 6. Stopping early.
# Data for 20160310 saved to job_listings\job_listings_20160310.json.
# Scraping data from 20160515 to 20160515...
# No job postings found on page 6. Stopping early.
# Data for 20160311 saved to job_listings\job_listings_20160311.json.
# Scraping data from 20160516 to 20160516...
# No job postings found on page 5. Stopping early.
# Data for 20160316 saved to job_listings\job_listings_20160316.json.
# Scraping data from 20160517 to 20160517...
# No job postings found on page 5. Stopping early.
# Data for 20160404 saved to job_listings\job_listings_20160404.json.
# Scraping data from 20160518 to 20160518...
# No job postings found on page 2. Stopping early.
# Data for 20160514 saved to job_listings\job_listings_20160514.json.
# Scraping data from 20160519 to 20160519...
# No job postings found on page 5. Stopping early.
# Data for 20160321 saved to job_listings\job_listings_20160321.json.
# Scraping data from 20160520 to 20160520...
# No job postings found on page 5. Stopping early.
# Data for 20160401 saved to job_listings\job_listings_20160401.json.
# Scraping data from 20160521 to 20160521...
# No job postings found on page 5. Stopping early.
# Data for 20160407 saved to job_listings\job_listings_20160407.json.
# Scraping data from 20160522 to 20160522...
# No job postings found on page 6. Stopping early.
# Data for 20160318 saved to job_listings\job_listings_20160318.json.
# Scraping data from 20160523 to 20160523...
# No job postings found on page 2. Stopping early.
# Data for 20160515 saved to job_listings\job_listings_20160515.json.
# Scraping data from 20160524 to 20160524...
# No job postings found on page 6. Stopping early.
# Data for 20160307 saved to job_listings\job_listings_20160307.json.
# Scraping data from 20160525 to 20160525...
# No job postings found on page 5. Stopping early.
# Data for 20160406 saved to job_listings\job_listings_20160406.json.
# Scraping data from 20160526 to 20160526...
# No job postings found on page 5. Stopping early.
# Data for 20160330 saved to job_listings\job_listings_20160330.json.
# Scraping data from 20160527 to 20160527...
# No job postings found on page 5. Stopping early.
# Data for 20160418 saved to job_listings\job_listings_20160418.json.
# Scraping data from 20160528 to 20160528...
# No job postings found on page 6. Stopping early.
# Data for 20160317 saved to job_listings\job_listings_20160317.json.
# Scraping data from 20160529 to 20160529...
# No job postings found on page 2. Stopping early.
# Data for 20160522 saved to job_listings\job_listings_20160522.json.
# Scraping data from 20160530 to 20160530...
# No job postings found on page 10. Stopping early.
# Data for 20160122 saved to job_listings\job_listings_20160122.json.
# Scraping data from 20160531 to 20160531...
# No job postings found on page 2. Stopping early.
# Data for 20160516 saved to job_listings\job_listings_20160516.json.
# Scraping data from 20160601 to 20160601...
# No job postings found on page 5. Stopping early.
# Data for 20160408 saved to job_listings\job_listings_20160408.json.
# Scraping data from 20160602 to 20160602...
# No job postings found on page 3. Stopping early.
# Data for 20160505 saved to job_listings\job_listings_20160505.json.
# Scraping data from 20160603 to 20160603...
# No job postings found on page 4. Stopping early.
# Data for 20160426 saved to job_listings\job_listings_20160426.json.
# Scraping data from 20160604 to 20160604...
# No job postings found on page 2. Stopping early.
# Data for 20160529 saved to job_listings\job_listings_20160529.json.
# Scraping data from 20160605 to 20160605...
# No job postings found on page 5. Stopping early.
# Data for 20160405 saved to job_listings\job_listings_20160405.json.
# Scraping data from 20160606 to 20160606...
# No job postings found on page 2. Stopping early.
# Data for 20160604 saved to job_listings\job_listings_20160604.json.
# Scraping data from 20160607 to 20160607...
# No job postings found on page 2. Stopping early.
# Data for 20160605 saved to job_listings\job_listings_20160605.json.
# Scraping data from 20160608 to 20160608...
# No job postings found on page 5. Stopping early.
# Data for 20160414 saved to job_listings\job_listings_20160414.json.
# Scraping data from 20160609 to 20160609...
# No job postings found on page 2. Stopping early.
# Data for 20160521 saved to job_listings\job_listings_20160521.json.
# Scraping data from 20160610 to 20160610...
# No job postings found on page 5. Stopping early.
# Data for 20160412 saved to job_listings\job_listings_20160412.json.
# Scraping data from 20160611 to 20160611...
# No job postings found on page 5. Stopping early.
# Data for 20160411 saved to job_listings\job_listings_20160411.json.
# Scraping data from 20160612 to 20160612...
# No job postings found on page 1. Stopping early.
# No data found for 20160612.
# Scraping data from 20160613 to 20160613...
# No job postings found on page 5. Stopping early.
# Data for 20160419 saved to job_listings\job_listings_20160419.json.
# Scraping data from 20160614 to 20160614...
# No job postings found on page 2. Stopping early.
# Data for 20160611 saved to job_listings\job_listings_20160611.json.
# Scraping data from 20160615 to 20160615...
# No job postings found on page 5. Stopping early.
# Data for 20160420 saved to job_listings\job_listings_20160420.json.
# Scraping data from 20160616 to 20160616...
# No job postings found on page 2. Stopping early.
# Data for 20160528 saved to job_listings\job_listings_20160528.json.
# Scraping data from 20160617 to 20160617...
# No job postings found on page 6. Stopping early.
# Data for 20160415 saved to job_listings\job_listings_20160415.json.
# Scraping data from 20160618 to 20160618...
# No job postings found on page 2. Stopping early.
# Data for 20160618 saved to job_listings\job_listings_20160618.json.
# Scraping data from 20160619 to 20160619...
# No job postings found on page 4. Stopping early.
# Data for 20160506 saved to job_listings\job_listings_20160506.json.
# Scraping data from 20160620 to 20160620...
# No job postings found on page 1. Stopping early.
# No data found for 20160619.
# Scraping data from 20160621 to 20160621...
# No job postings found on page 4. Stopping early.
# Data for 20160502 saved to job_listings\job_listings_20160502.json.
# Scraping data from 20160622 to 20160622...
# No job postings found on page 4. Stopping early.
# Data for 20160509 saved to job_listings\job_listings_20160509.json.
# Scraping data from 20160623 to 20160623...
# No job postings found on page 5. Stopping early.
# Data for 20160425 saved to job_listings\job_listings_20160425.json.
# Scraping data from 20160624 to 20160624...
# No job postings found on page 4. Stopping early.
# Data for 20160512 saved to job_listings\job_listings_20160512.json.
# Scraping data from 20160625 to 20160625...
# No job postings found on page 4. Stopping early.
# Data for 20160510 saved to job_listings\job_listings_20160510.json.
# Scraping data from 20160626 to 20160626...
# No job postings found on page 1. Stopping early.
# No data found for 20160626.
# Scraping data from 20160627 to 20160627...
# No job postings found on page 5. Stopping early.
# Data for 20160428 saved to job_listings\job_listings_20160428.json.
# Scraping data from 20160628 to 20160628...
# No job postings found on page 4. Stopping early.
# Data for 20160511 saved to job_listings\job_listings_20160511.json.
# Scraping data from 20160629 to 20160629...
# No job postings found on page 7. Stopping early.
# Data for 20160421 saved to job_listings\job_listings_20160421.json.
# Scraping data from 20160630 to 20160630...
# No job postings found on page 2. Stopping early.
# Data for 20160625 saved to job_listings\job_listings_20160625.json.
# Scraping data from 20160701 to 20160701...
# No job postings found on page 6. Stopping early.
# Data for 20160427 saved to job_listings\job_listings_20160427.json.
# Scraping data from 20160702 to 20160702...
# No job postings found on page 6. Stopping early.
# Data for 20160429 saved to job_listings\job_listings_20160429.json.
# Scraping data from 20160703 to 20160703...
# No job postings found on page 4. Stopping early.
# Data for 20160531 saved to job_listings\job_listings_20160531.json.
# Scraping data from 20160704 to 20160704...
# No job postings found on page 5. Stopping early.
# Data for 20160524 saved to job_listings\job_listings_20160524.json.
# Scraping data from 20160705 to 20160705...
# No job postings found on page 5. Stopping early.
# Data for 20160527 saved to job_listings\job_listings_20160527.json.
# Scraping data from 20160706 to 20160706...
# No job postings found on page 2. Stopping early.
# Data for 20160703 saved to job_listings\job_listings_20160703.json.
# Scraping data from 20160707 to 20160707...
# No job postings found on page 4. Stopping early.
# Data for 20160603 saved to job_listings\job_listings_20160603.json.
# Scraping data from 20160708 to 20160708...
# No job postings found on page 9. Stopping early.
# Data for 20160314 saved to job_listings\job_listings_20160314.json.
# Scraping data from 20160709 to 20160709...
# No job postings found on page 2. Stopping early.
# Data for 20160702 saved to job_listings\job_listings_20160702.json.
# Scraping data from 20160710 to 20160710...
# No job postings found on page 5. Stopping early.
# Data for 20160517 saved to job_listings\job_listings_20160517.json.
# Scraping data from 20160711 to 20160711...
# No job postings found on page 4. Stopping early.
# Data for 20160608 saved to job_listings\job_listings_20160608.json.
# Scraping data from 20160712 to 20160712...
# No job postings found on page 4. Stopping early.
# Data for 20160615 saved to job_listings\job_listings_20160615.json.
# Scraping data from 20160713 to 20160713...
# No job postings found on page 6. Stopping early.
# Data for 20160503 saved to job_listings\job_listings_20160503.json.
# Scraping data from 20160714 to 20160714...
# No job postings found on page 6. Stopping early.
# Data for 20160513 saved to job_listings\job_listings_20160513.json.
# Scraping data from 20160715 to 20160715...
# No job postings found on page 5. Stopping early.
# Data for 20160602 saved to job_listings\job_listings_20160602.json.
# Scraping data from 20160716 to 20160716...
# No job postings found on page 4. Stopping early.
# Data for 20160616 saved to job_listings\job_listings_20160616.json.
# Scraping data from 20160717 to 20160717...
# No job postings found on page 2. Stopping early.
# Data for 20160709 saved to job_listings\job_listings_20160709.json.
# Scraping data from 20160718 to 20160718...
# No job postings found on page 6. Stopping early.
# Data for 20160518 saved to job_listings\job_listings_20160518.json.
# Scraping data from 20160719 to 20160719...
# No job postings found on page 5. Stopping early.
# Data for 20160530 saved to job_listings\job_listings_20160530.json.
# Scraping data from 20160720 to 20160720...
# No job postings found on page 2. Stopping early.
# Data for 20160710 saved to job_listings\job_listings_20160710.json.
# Scraping data from 20160721 to 20160721...
# No job postings found on page 7. Stopping early.
# Data for 20160504 saved to job_listings\job_listings_20160504.json.
# Scraping data from 20160722 to 20160722...
# No job postings found on page 5. Stopping early.
# Data for 20160610 saved to job_listings\job_listings_20160610.json.
# Scraping data from 20160723 to 20160723...
# No job postings found on page 6. Stopping early.
# Data for 20160520 saved to job_listings\job_listings_20160520.json.
# Scraping data from 20160724 to 20160724...
# No job postings found on page 5. Stopping early.
# Data for 20160617 saved to job_listings\job_listings_20160617.json.
# Scraping data from 20160725 to 20160725...
# No job postings found on page 6. Stopping early.
# Data for 20160519 saved to job_listings\job_listings_20160519.json.
# Scraping data from 20160726 to 20160726...
# No job postings found on page 2. Stopping early.
# Data for 20160717 saved to job_listings\job_listings_20160717.json.
# Scraping data from 20160727 to 20160727...
# No job postings found on page 5. Stopping early.
# Data for 20160614 saved to job_listings\job_listings_20160614.json.
# Scraping data from 20160728 to 20160728...
# No job postings found on page 6. Stopping early.
# Data for 20160523 saved to job_listings\job_listings_20160523.json.
# Scraping data from 20160729 to 20160729...
# No job postings found on page 4. Stopping early.
# Data for 20160622 saved to job_listings\job_listings_20160622.json.
# Scraping data from 20160730 to 20160730...
# No job postings found on page 2. Stopping early.
# Data for 20160723 saved to job_listings\job_listings_20160723.json.
# Scraping data from 20160731 to 20160731...
# No job postings found on page 2. Stopping early.
# Data for 20160716 saved to job_listings\job_listings_20160716.json.
# Scraping data from 20160801 to 20160801...
# No job postings found on page 5. Stopping early.
# Data for 20160621 saved to job_listings\job_listings_20160621.json.
# Scraping data from 20160802 to 20160802...
# No job postings found on page 6. Stopping early.
# Data for 20160601 saved to job_listings\job_listings_20160601.json.
# Scraping data from 20160803 to 20160803...
# No job postings found on page 2. Stopping early.
# Data for 20160724 saved to job_listings\job_listings_20160724.json.
# Scraping data from 20160804 to 20160804...
# No job postings found on page 6. Stopping early.
# Data for 20160525 saved to job_listings\job_listings_20160525.json.
# Scraping data from 20160805 to 20160805...
# No job postings found on page 5. Stopping early.
# Data for 20160613 saved to job_listings\job_listings_20160613.json.
# Scraping data from 20160806 to 20160806...
# No job postings found on page 2. Stopping early.
# Data for 20160730 saved to job_listings\job_listings_20160730.json.
# Scraping data from 20160807 to 20160807...
# No job postings found on page 6. Stopping early.
# Data for 20160607 saved to job_listings\job_listings_20160607.json.
# Scraping data from 20160808 to 20160808...
# No job postings found on page 2. Stopping early.
# Data for 20160731 saved to job_listings\job_listings_20160731.json.
# Scraping data from 20160809 to 20160809...
# No job postings found on page 2. Stopping early.
# Data for 20160806 saved to job_listings\job_listings_20160806.json.
# Scraping data from 20160810 to 20160810...
# No job postings found on page 4. Stopping early.
# Data for 20160624 saved to job_listings\job_listings_20160624.json.
# Scraping data from 20160811 to 20160811...
# No job postings found on page 2. Stopping early.
# Data for 20160807 saved to job_listings\job_listings_20160807.json.
# Scraping data from 20160812 to 20160812...
# No job postings found on page 5. Stopping early.
# Data for 20160623 saved to job_listings\job_listings_20160623.json.
# Scraping data from 20160813 to 20160813...
# No job postings found on page 2. Stopping early.
# Data for 20160813 saved to job_listings\job_listings_20160813.json.
# Scraping data from 20160814 to 20160814...
# No job postings found on page 4. Stopping early.
# Data for 20160628 saved to job_listings\job_listings_20160628.json.
# Scraping data from 20160815 to 20160815...
# No job postings found on page 4. Stopping early.
# Data for 20160630 saved to job_listings\job_listings_20160630.json.
# Scraping data from 20160816 to 20160816...
# No job postings found on page 5. Stopping early.
# Data for 20160627 saved to job_listings\job_listings_20160627.json.
# Scraping data from 20160817 to 20160817...
# No job postings found on page 6. Stopping early.
# Data for 20160606 saved to job_listings\job_listings_20160606.json.
# Scraping data from 20160818 to 20160818...
# No job postings found on page 6. Stopping early.
# Data for 20160620 saved to job_listings\job_listings_20160620.json.
# Scraping data from 20160819 to 20160819...
# No job postings found on page 2. Stopping early.
# Data for 20160814 saved to job_listings\job_listings_20160814.json.
# Scraping data from 20160820 to 20160820...
# No job postings found on page 7. Stopping early.
# Data for 20160526 saved to job_listings\job_listings_20160526.json.
# Scraping data from 20160821 to 20160821...
# No job postings found on page 2. Stopping early.
# Data for 20160821 saved to job_listings\job_listings_20160821.json.
# Scraping data from 20160822 to 20160822...
# No job postings found on page 5. Stopping early.
# Data for 20160629 saved to job_listings\job_listings_20160629.json.
# Scraping data from 20160823 to 20160823...
# No job postings found on page 2. Stopping early.
# Data for 20160820 saved to job_listings\job_listings_20160820.json.
# Scraping data from 20160824 to 20160824...
# No job postings found on page 3. Stopping early.
# Data for 20160726 saved to job_listings\job_listings_20160726.json.
# Scraping data from 20160825 to 20160825...
# No job postings found on page 3. Stopping early.
# Data for 20160727 saved to job_listings\job_listings_20160727.json.
# Scraping data from 20160826 to 20160826...
# No job postings found on page 4. Stopping early.
# Data for 20160713 saved to job_listings\job_listings_20160713.json.
# Scraping data from 20160827 to 20160827...
# No job postings found on page 1. Stopping early.
# No data found for 20160827.
# Scraping data from 20160828 to 20160828...
# No job postings found on page 4. Stopping early.
# Data for 20160721 saved to job_listings\job_listings_20160721.json.
# Scraping data from 20160829 to 20160829...
# No job postings found on page 1. Stopping early.
# No data found for 20160828.
# Scraping data from 20160830 to 20160830...
# No job postings found on page 4. Stopping early.
# Data for 20160707 saved to job_listings\job_listings_20160707.json.
# Scraping data from 20160831 to 20160831...
# No job postings found on page 3. Stopping early.
# Data for 20160728 saved to job_listings\job_listings_20160728.json.
# Scraping data from 20160901 to 20160901...
# No job postings found on page 4. Stopping early.
# Data for 20160720 saved to job_listings\job_listings_20160720.json.
# Scraping data from 20160902 to 20160902...
# No job postings found on page 5. Stopping early.
# Data for 20160701 saved to job_listings\job_listings_20160701.json.
# Scraping data from 20160903 to 20160903...
# No job postings found on page 1. Stopping early.
# No data found for 20160903.
# Scraping data from 20160904 to 20160904...
# No job postings found on page 4. Stopping early.
# Data for 20160722 saved to job_listings\job_listings_20160722.json.
# Scraping data from 20160905 to 20160905...
# No job postings found on page 1. Stopping early.
# No data found for 20160904.
# Scraping data from 20160906 to 20160906...
# No job postings found on page 5. Stopping early.
# Data for 20160704 saved to job_listings\job_listings_20160704.json.
# Scraping data from 20160907 to 20160907...
# No job postings found on page 5. Stopping early.
# Data for 20160712 saved to job_listings\job_listings_20160712.json.
# Scraping data from 20160908 to 20160908...
# No job postings found on page 4. Stopping early.
# Data for 20160803 saved to job_listings\job_listings_20160803.json.
# Scraping data from 20160909 to 20160909...
# No job postings found on page 5. Stopping early.
# Data for 20160715 saved to job_listings\job_listings_20160715.json.
# Scraping data from 20160910 to 20160910...
# No job postings found on page 5. Stopping early.
# Data for 20160706 saved to job_listings\job_listings_20160706.json.
# Scraping data from 20160911 to 20160911...
# No job postings found on page 4. Stopping early.
# Data for 20160805 saved to job_listings\job_listings_20160805.json.
# Scraping data from 20160912 to 20160912...
# No job postings found on page 4. Stopping early.
# Data for 20160729 saved to job_listings\job_listings_20160729.json.
# Scraping data from 20160913 to 20160913...
# No job postings found on page 5. Stopping early.
# Data for 20160711 saved to job_listings\job_listings_20160711.json.
# Scraping data from 20160914 to 20160914...
# No job postings found on page 2. Stopping early.
# Data for 20160911 saved to job_listings\job_listings_20160911.json.
# Scraping data from 20160915 to 20160915...
# No job postings found on page 4. Stopping early.
# Data for 20160725 saved to job_listings\job_listings_20160725.json.
# Scraping data from 20160916 to 20160916...
# No job postings found on page 2. Stopping early.
# Data for 20160910 saved to job_listings\job_listings_20160910.json.
# Scraping data from 20160917 to 20160917...
# No job postings found on page 6. Stopping early.
# Data for 20160705 saved to job_listings\job_listings_20160705.json.
# Scraping data from 20160918 to 20160918...
# No job postings found on page 4. Stopping early.
# Data for 20160802 saved to job_listings\job_listings_20160802.json.
# Scraping data from 20160919 to 20160919...
# No job postings found on page 4. Stopping early.
# Data for 20160801 saved to job_listings\job_listings_20160801.json.
# Scraping data from 20160920 to 20160920...
# No job postings found on page 2. Stopping early.
# Data for 20160917 saved to job_listings\job_listings_20160917.json.
# Scraping data from 20160921 to 20160921...
# No job postings found on page 5. Stopping early.
# Data for 20160719 saved to job_listings\job_listings_20160719.json.
# Scraping data from 20160922 to 20160922...
# No job postings found on page 5. Stopping early.
# Data for 20160718 saved to job_listings\job_listings_20160718.json.
# Scraping data from 20160923 to 20160923...
# No job postings found on page 5. Stopping early.
# Data for 20160804 saved to job_listings\job_listings_20160804.json.
# Scraping data from 20160924 to 20160924...
# No job postings found on page 4. Stopping early.
# Data for 20160809 saved to job_listings\job_listings_20160809.json.
# Scraping data from 20160925 to 20160925...
# No job postings found on page 2. Stopping early.
# Data for 20160918 saved to job_listings\job_listings_20160918.json.
# Scraping data from 20160926 to 20160926...
# No job postings found on page 4. Stopping early.
# Data for 20160824 saved to job_listings\job_listings_20160824.json.
# Scraping data from 20160927 to 20160927...
# No job postings found on page 2. Stopping early.
# Data for 20160924 saved to job_listings\job_listings_20160924.json.
# Scraping data from 20160928 to 20160928...
# No job postings found on page 2. Stopping early.
# Data for 20160925 saved to job_listings\job_listings_20160925.json.
# Scraping data from 20160929 to 20160929...
# No job postings found on page 6. Stopping early.
# Data for 20160714 saved to job_listings\job_listings_20160714.json.
# Scraping data from 20160930 to 20160930...
# No job postings found on page 4. Stopping early.
# Data for 20160818 saved to job_listings\job_listings_20160818.json.
# Scraping data from 20161001 to 20161001...
# No job postings found on page 4. Stopping early.
# Data for 20160817 saved to job_listings\job_listings_20160817.json.
# Scraping data from 20161002 to 20161002...
# No job postings found on page 5. Stopping early.
# Data for 20160810 saved to job_listings\job_listings_20160810.json.
# Scraping data from 20161003 to 20161003...
# No job postings found on page 2. Stopping early.
# Data for 20161001 saved to job_listings\job_listings_20161001.json.
# Scraping data from 20161004 to 20161004...
# No job postings found on page 7. Stopping early.
# Data for 20160708 saved to job_listings\job_listings_20160708.json.
# Scraping data from 20161005 to 20161005...
# No job postings found on page 5. Stopping early.
# Data for 20160812 saved to job_listings\job_listings_20160812.json.
# Scraping data from 20161006 to 20161006...
# No job postings found on page 2. Stopping early.
# Data for 20161002 saved to job_listings\job_listings_20161002.json.
# Scraping data from 20161007 to 20161007...
# No job postings found on page 5. Stopping early.
# Data for 20160815 saved to job_listings\job_listings_20160815.json.
# Scraping data from 20161008 to 20161008...
# No job postings found on page 5. Stopping early.
# Data for 20160808 saved to job_listings\job_listings_20160808.json.
# Scraping data from 20161009 to 20161009...
# No job postings found on page 5. Stopping early.
# Data for 20160811 saved to job_listings\job_listings_20160811.json.
# Scraping data from 20161010 to 20161010...
# No job postings found on page 4. Stopping early.
# Data for 20160823 saved to job_listings\job_listings_20160823.json.
# Scraping data from 20161011 to 20161011...
# No job postings found on page 5. Stopping early.
# Data for 20160822 saved to job_listings\job_listings_20160822.json.
# Scraping data from 20161012 to 20161012...
# No job postings found on page 4. Stopping early.
# Data for 20160826 saved to job_listings\job_listings_20160826.json.
# Scraping data from 20161013 to 20161013...
# No job postings found on page 2. Stopping early.
# Data for 20161009 saved to job_listings\job_listings_20161009.json.
# Scraping data from 20161014 to 20161014...
# No job postings found on page 5. Stopping early.
# Data for 20160816 saved to job_listings\job_listings_20160816.json.
# Scraping data from 20161015 to 20161015...
# No job postings found on page 2. Stopping early.
# Data for 20161008 saved to job_listings\job_listings_20161008.json.
# Scraping data from 20161016 to 20161016...
# No job postings found on page 5. Stopping early.
# Data for 20160825 saved to job_listings\job_listings_20160825.json.
# Scraping data from 20161017 to 20161017...
# No job postings found on page 2. Stopping early.
# Data for 20161015 saved to job_listings\job_listings_20161015.json.
# Scraping data from 20161018 to 20161018...
# No job postings found on page 2. Stopping early.
# Data for 20161016 saved to job_listings\job_listings_20161016.json.
# Scraping data from 20161019 to 20161019...
# No job postings found on page 10. Stopping early.
# Data for 20160609 saved to job_listings\job_listings_20160609.json.
# Scraping data from 20161020 to 20161020...
# No job postings found on page 5. Stopping early.
# Data for 20160819 saved to job_listings\job_listings_20160819.json.
# Scraping data from 20161021 to 20161021...
# No job postings found on page 5. Stopping early.
# Data for 20160829 saved to job_listings\job_listings_20160829.json.
# Scraping data from 20161022 to 20161022...
# No job postings found on page 5. Stopping early.
# Data for 20160831 saved to job_listings\job_listings_20160831.json.
# Scraping data from 20161023 to 20161023...
# No job postings found on page 2. Stopping early.
# No job postings found on page 5. Stopping early.
# Data for 20161022 saved to job_listings\job_listings_20161022.json.
# Scraping data from 20161024 to 20161024...
# Data for 20160901 saved to job_listings\job_listings_20160901.json.
# Scraping data from 20161025 to 20161025...
# No job postings found on page 2. Stopping early.
# Data for 20161023 saved to job_listings\job_listings_20161023.json.
# Scraping data from 20161026 to 20161026...
# No job postings found on page 5. Stopping early.
# Data for 20160830 saved to job_listings\job_listings_20160830.json.
# Scraping data from 20161027 to 20161027...
# No job postings found on page 5. Stopping early.
# Data for 20160902 saved to job_listings\job_listings_20160902.json.
# Scraping data from 20161028 to 20161028...
# No job postings found on page 4. Stopping early.
# Data for 20160921 saved to job_listings\job_listings_20160921.json.
# Scraping data from 20161029 to 20161029...
# No job postings found on page 5. Stopping early.
# Data for 20160905 saved to job_listings\job_listings_20160905.json.
# Scraping data from 20161030 to 20161030...
# No job postings found on page 5. Stopping early.
# Data for 20160906 saved to job_listings\job_listings_20160906.json.
# Scraping data from 20161031 to 20161031...
# No job postings found on page 2. Stopping early.No job postings found on page 1. Stopping early.
#
# No data found for 20161030.
# Scraping data from 20161101 to 20161101...
# Data for 20161029 saved to job_listings\job_listings_20161029.json.
# Scraping data from 20161102 to 20161102...
# No job postings found on page 5. Stopping early.
# Data for 20160916 saved to job_listings\job_listings_20160916.json.
# Scraping data from 20161103 to 20161103...
# No job postings found on page 5. Stopping early.
# Data for 20160909 saved to job_listings\job_listings_20160909.json.
# Scraping data from 20161104 to 20161104...
# No job postings found on page 5. Stopping early.
# Data for 20160914 saved to job_listings\job_listings_20160914.json.
# Scraping data from 20161105 to 20161105...
# No job postings found on page 5. Stopping early.
# Data for 20160912 saved to job_listings\job_listings_20160912.json.
# Scraping data from 20161106 to 20161106...
# No job postings found on page 1. Stopping early.
# No data found for 20161105.
# Scraping data from 20161107 to 20161107...
# No job postings found on page 5. Stopping early.
# Data for 20160907 saved to job_listings\job_listings_20160907.json.
# Scraping data from 20161108 to 20161108...
# No job postings found on page 2. Stopping early.
# Data for 20161106 saved to job_listings\job_listings_20161106.json.
# Scraping data from 20161109 to 20161109...
# No job postings found on page 6. Stopping early.
# Data for 20160908 saved to job_listings\job_listings_20160908.json.
# Scraping data from 20161110 to 20161110...
# No job postings found on page 4. Stopping early.
# Data for 20160927 saved to job_listings\job_listings_20160927.json.
# Scraping data from 20161111 to 20161111...
# No job postings found on page 5. Stopping early.
# Data for 20160922 saved to job_listings\job_listings_20160922.json.
# Scraping data from 20161112 to 20161112...
# No job postings found on page 5. Stopping early.
# Data for 20160926 saved to job_listings\job_listings_20160926.json.
# Scraping data from 20161113 to 20161113...
# No job postings found on page 1. Stopping early.
# No data found for 20161113.
# Scraping data from 20161114 to 20161114...
# No job postings found on page 5. Stopping early.
# Data for 20160930 saved to job_listings\job_listings_20160930.json.
# Scraping data from 20161115 to 20161115...
# No job postings found on page 5. Stopping early.
# Data for 20160923 saved to job_listings\job_listings_20160923.json.
# Scraping data from 20161116 to 20161116...
# No job postings found on page 6. Stopping early.
# Data for 20160919 saved to job_listings\job_listings_20160919.json.
# Scraping data from 20161117 to 20161117...
# No job postings found on page 5. Stopping early.
# Data for 20160928 saved to job_listings\job_listings_20160928.json.
# Scraping data from 20161118 to 20161118...
# No job postings found on page 2. Stopping early.
# Data for 20161112 saved to job_listings\job_listings_20161112.json.
# Scraping data from 20161119 to 20161119...
# No job postings found on page 4. Stopping early.
# Data for 20161020 saved to job_listings\job_listings_20161020.json.
# Scraping data from 20161120 to 20161120...
# No job postings found on page 5. Stopping early.
# Data for 20161005 saved to job_listings\job_listings_20161005.json.
# Scraping data from 20161121 to 20161121...
# No job postings found on page 2. Stopping early.
# Data for 20161119 saved to job_listings\job_listings_20161119.json.
# Scraping data from 20161122 to 20161122...
# No job postings found on page 4. Stopping early.
# Data for 20161021 saved to job_listings\job_listings_20161021.json.
# Scraping data from 20161123 to 20161123...
# No job postings found on page 5. Stopping early.
# Data for 20161004 saved to job_listings\job_listings_20161004.json.
# Scraping data from 20161124 to 20161124...
# No job postings found on page 2. Stopping early.
# Data for 20161120 saved to job_listings\job_listings_20161120.json.
# Scraping data from 20161125 to 20161125...
# No job postings found on page 5. Stopping early.
# Data for 20161006 saved to job_listings\job_listings_20161006.json.
# Scraping data from 20161126 to 20161126...
# No job postings found on page 5. Stopping early.
# Data for 20161013 saved to job_listings\job_listings_20161013.json.
# ...
# Scraping data from 20240911 to 20240911...
# No job postings found on page 2. Stopping early.
# Data for 20240907 saved to job_listings\job_listings_20240907.json.
# Scraping data from 20240912 to 20240912...
# No job postings found on page 4. Stopping early.
# Data for 20240726 saved to job_listings\job_listings_20240726.json.
# Scraping data from 20240913 to 20240913...
# No job postings found on page 4. Stopping early.
# Data for 20240730 saved to job_listings\job_listings_20240730.json.
# Scraping data from 20240914 to 20240914...
# No job postings found on page 5. Stopping early.
# Data for 20240704 saved to job_listings\job_listings_20240704.json.
# Scraping data from 20240915 to 20240915...
# No job postings found on page 2. Stopping early.
# Data for 20240914 saved to job_listings\job_listings_20240914.json.
# Scraping data from 20240916 to 20240916...
# No job postings found on page 2. Stopping early.
# Data for 20240915 saved to job_listings\job_listings_20240915.json.
# Scraping data from 20240917 to 20240917...
# No job postings found on page 4. Stopping early.
# Data for 20240801 saved to job_listings\job_listings_20240801.json.
# Scraping data from 20240918 to 20240918...
# No job postings found on page 5. Stopping early.
# Data for 20240711 saved to job_listings\job_listings_20240711.json.
# Scraping data from 20240919 to 20240919...
# No job postings found on page 4. Stopping early.
# Data for 20240808 saved to job_listings\job_listings_20240808.json.
# Scraping data from 20240920 to 20240920...
# No job postings found on page 4. Stopping early.
# Data for 20240809 saved to job_listings\job_listings_20240809.json.
# Scraping data from 20240921 to 20240921...
# No job postings found on page 4. Stopping early.
# Data for 20240802 saved to job_listings\job_listings_20240802.json.
# Scraping data from 20240922 to 20240922...
# No job postings found on page 5. Stopping early.
# Data for 20240712 saved to job_listings\job_listings_20240712.json.
# Scraping data from 20240923 to 20240923...
# No job postings found on page 2. Stopping early.
# Data for 20240922 saved to job_listings\job_listings_20240922.json.
# Scraping data from 20240924 to 20240924...
# No job postings found on page 2. Stopping early.
# Data for 20240921 saved to job_listings\job_listings_20240921.json.
# Scraping data from 20240925 to 20240925...
# No job postings found on page 5. Stopping early.
# Data for 20240729 saved to job_listings\job_listings_20240729.json.
# Scraping data from 20240926 to 20240926...
# No job postings found on page 4. Stopping early.
# Data for 20240815 saved to job_listings\job_listings_20240815.json.
# Scraping data from 20240927 to 20240927...
# No job postings found on page 4. Stopping early.
# Data for 20240812 saved to job_listings\job_listings_20240812.json.
# Scraping data from 20240928 to 20240928...
# No job postings found on page 4. Stopping early.
# Data for 20240816 saved to job_listings\job_listings_20240816.json.
# Scraping data from 20240929 to 20240929...
# No job postings found on page 2. Stopping early.
# Data for 20240928 saved to job_listings\job_listings_20240928.json.
# Scraping data from 20240930 to 20240930...
# No job postings found on page 6. Stopping early.
# Data for 20240708 saved to job_listings\job_listings_20240708.json.
# Scraping data from 20241001 to 20241001...
# No job postings found on page 5. Stopping early.
# Data for 20240715 saved to job_listings\job_listings_20240715.json.
# Scraping data from 20241002 to 20241002...
# No job postings found on page 6. Stopping early.
# Data for 20240705 saved to job_listings\job_listings_20240705.json.
# Scraping data from 20241003 to 20241003...
# No job postings found on page 4. Stopping early.
# Data for 20240813 saved to job_listings\job_listings_20240813.json.
# Scraping data from 20241004 to 20241004...
# No job postings found on page 4. Stopping early.
# Data for 20240826 saved to job_listings\job_listings_20240826.json.
# Scraping data from 20241005 to 20241005...
# No job postings found on page 2. Stopping early.
# Data for 20240929 saved to job_listings\job_listings_20240929.json.
# Scraping data from 20241006 to 20241006...
# No job postings found on page 5. Stopping early.
# Data for 20240807 saved to job_listings\job_listings_20240807.json.
# Scraping data from 20241007 to 20241007...
# No job postings found on page 5. Stopping early.
# Data for 20240806 saved to job_listings\job_listings_20240806.json.
# Scraping data from 20241008 to 20241008...
# No job postings found on page 4. Stopping early.
# Data for 20240827 saved to job_listings\job_listings_20240827.json.
# Scraping data from 20241009 to 20241009...
# No job postings found on page 2. Stopping early.
# Data for 20241006 saved to job_listings\job_listings_20241006.json.
# Scraping data from 20241010 to 20241010...
# No job postings found on page 4. Stopping early.
# Data for 20240814 saved to job_listings\job_listings_20240814.json.
# Scraping data from 20241011 to 20241011...
# No job postings found on page 5. Stopping early.
# Data for 20240805 saved to job_listings\job_listings_20240805.json.
# Scraping data from 20241012 to 20241012...
# No job postings found on page 2. Stopping early.
# No job postings found on page 4. Stopping early.
# Data for 20240822 saved to job_listings\job_listings_20240822.json.
# Scraping data from 20241013 to 20241013...
# Data for 20241005 saved to job_listings\job_listings_20241005.json.
# Scraping data from 20241014 to 20241014...
# No job postings found on page 4. Stopping early.
# Data for 20240821 saved to job_listings\job_listings_20240821.json.
# Scraping data from 20241015 to 20241015...
# No job postings found on page 4. Stopping early.
# Data for 20240828 saved to job_listings\job_listings_20240828.json.
# Scraping data from 20241016 to 20241016...
# No job postings found on page 2. Stopping early.
# Data for 20241012 saved to job_listings\job_listings_20241012.json.
# Scraping data from 20241017 to 20241017...
# No job postings found on page 2. Stopping early.
# Data for 20241013 saved to job_listings\job_listings_20241013.json.
# Scraping data from 20241018 to 20241018...
# No job postings found on page 5. Stopping early.
# Data for 20240819 saved to job_listings\job_listings_20240819.json.
# Scraping data from 20241019 to 20241019...
# No job postings found on page 4. Stopping early.
# Data for 20240829 saved to job_listings\job_listings_20240829.json.
# Scraping data from 20241020 to 20241020...
# No job postings found on page 4. Stopping early.
# Data for 20240823 saved to job_listings\job_listings_20240823.json.
# Scraping data from 20241021 to 20241021...
# No job postings found on page 2. Stopping early.
# Data for 20241019 saved to job_listings\job_listings_20241019.json.
# Scraping data from 20241022 to 20241022...
# No job postings found on page 2. Stopping early.
# Data for 20241020 saved to job_listings\job_listings_20241020.json.
# Scraping data from 20241023 to 20241023...
# No job postings found on page 4. Stopping early.
# Data for 20240830 saved to job_listings\job_listings_20240830.json.
# Scraping data from 20241024 to 20241024...
# No job postings found on page 4. Stopping early.
# Data for 20240904 saved to job_listings\job_listings_20240904.json.
# Scraping data from 20241025 to 20241025...
# No job postings found on page 4. Stopping early.
# Data for 20240913 saved to job_listings\job_listings_20240913.json.
# Scraping data from 20241026 to 20241026...
# No job postings found on page 5. Stopping early.
# Data for 20240820 saved to job_listings\job_listings_20240820.json.
# Scraping data from 20241027 to 20241027...
# No job postings found on page 2. Stopping early.
# Data for 20241026 saved to job_listings\job_listings_20241026.json.
# Scraping data from 20241028 to 20241028...
# No job postings found on page 4. Stopping early.
# Data for 20240906 saved to job_listings\job_listings_20240906.json.
# Scraping data from 20241029 to 20241029...
# No job postings found on page 4. Stopping early.
# Data for 20240905 saved to job_listings\job_listings_20240905.json.
# Scraping data from 20241030 to 20241030...
# No job postings found on page 2. Stopping early.
# Data for 20241027 saved to job_listings\job_listings_20241027.json.
# Scraping data from 20241031 to 20241031...
# No job postings found on page 5. Stopping early.
# Data for 20240902 saved to job_listings\job_listings_20240902.json.
# Scraping data from 20241101 to 20241101...
# No job postings found on page 3. Stopping early.
# Data for 20240926 saved to job_listings\job_listings_20240926.json.
# Scraping data from 20241102 to 20241102...
# No job postings found on page 2. Stopping early.
# Data for 20241102 saved to job_listings\job_listings_20241102.json.
# Scraping data from 20241103 to 20241103...
# No job postings found on page 5. Stopping early.
# Data for 20240909 saved to job_listings\job_listings_20240909.json.
# Scraping data from 20241104 to 20241104...
# No job postings found on page 1. Stopping early.
# No data found for 20241103.
# Scraping data from 20241105 to 20241105...
# No job postings found on page 5. Stopping early.
# Data for 20240910 saved to job_listings\job_listings_20240910.json.
# Scraping data from 20241106 to 20241106...
# No job postings found on page 4. Stopping early.
# Data for 20240919 saved to job_listings\job_listings_20240919.json.
# Scraping data from 20241107 to 20241107...
# No job postings found on page 4. Stopping early.
# Data for 20240927 saved to job_listings\job_listings_20240927.json.
# Scraping data from 20241108 to 20241108...
# No job postings found on page 5. Stopping early.
# Data for 20240912 saved to job_listings\job_listings_20240912.json.
# Scraping data from 20241109 to 20241109...
# No job postings found on page 4. Stopping early.
# Data for 20240924 saved to job_listings\job_listings_20240924.json.
# Scraping data from 20241110 to 20241110...
# No job postings found on page 5. Stopping early.
# No job postings found on page 5. Stopping early.
# Data for 20240911 saved to job_listings\job_listings_20240911.json.
# Scraping data from 20241111 to 20241111...
# Data for 20240903 saved to job_listings\job_listings_20240903.json.
# Scraping data from 20241112 to 20241112...
# No job postings found on page 4. Stopping early.
# Data for 20240918 saved to job_listings\job_listings_20240918.json.
# Scraping data from 20241113 to 20241113...
# No job postings found on page 4. Stopping early.
# Data for 20240925 saved to job_listings\job_listings_20240925.json.
# Scraping data from 20241114 to 20241114...
# No job postings found on page 2. Stopping early.
# Data for 20241110 saved to job_listings\job_listings_20241110.json.
# Scraping data from 20241115 to 20241115...
# No job postings found on page 2. Stopping early.
# Data for 20241109 saved to job_listings\job_listings_20241109.json.
# Scraping data from 20241116 to 20241116...
# No job postings found on page 1. Stopping early.
# No data found for 20241116.
# Scraping data from 20241117 to 20241117...
# No job postings found on page 4. Stopping early.
# Data for 20240930 saved to job_listings\job_listings_20240930.json.
# Scraping data from 20241118 to 20241118...
# No job postings found on page 3. Stopping early.
# Data for 20241022 saved to job_listings\job_listings_20241022.json.
# Scraping data from 20241119 to 20241119...
# No job postings found on page 4. Stopping early.
# Data for 20240923 saved to job_listings\job_listings_20240923.json.
# Scraping data from 20241120 to 20241120...
# No job postings found on page 1. Stopping early.
# No data found for 20241117.
# Scraping data from 20241121 to 20241121...
# No job postings found on page 2. Stopping early.
# Data for 20241121 saved to job_listings\job_listings_20241121.json.
# No job postings found on page 4. Stopping early.
# Data for 20241015 saved to job_listings\job_listings_20241015.json.
# No job postings found on page 5. Stopping early.
# Data for 20240917 saved to job_listings\job_listings_20240917.json.
# No job postings found on page 5. Stopping early.
# Data for 20240920 saved to job_listings\job_listings_20240920.json.
# No job postings found on page 3. Stopping early.
# Data for 20241029 saved to job_listings\job_listings_20241029.json.
# No job postings found on page 5. Stopping early.
# Data for 20240916 saved to job_listings\job_listings_20240916.json.
# No job postings found on page 2. Stopping early.
# Data for 20241120 saved to job_listings\job_listings_20241120.json.
# No job postings found on page 4. Stopping early.
# Data for 20241018 saved to job_listings\job_listings_20241018.json.
# No job postings found on page 2. Stopping early.
# Data for 20241114 saved to job_listings\job_listings_20241114.json.
# No job postings found on page 2. Stopping early.
# Data for 20241104 saved to job_listings\job_listings_20241104.json.
# No job postings found on page 4. Stopping early.
# Data for 20241016 saved to job_listings\job_listings_20241016.json.
# No job postings found on page 4. Stopping early.
# Data for 20241014 saved to job_listings\job_listings_20241014.json.
# No job postings found on page 2. Stopping early.
# Data for 20241119 saved to job_listings\job_listings_20241119.json.
# No job postings found on page 2. Stopping early.No job postings found on page 2. Stopping early.
#
# Data for 20241115 saved to job_listings\job_listings_20241115.json.
# Data for 20241118 saved to job_listings\job_listings_20241118.json.
# No job postings found on page 2. Stopping early.
# Data for 20241112 saved to job_listings\job_listings_20241112.json.
# No job postings found on page 4. Stopping early.
# Data for 20241021 saved to job_listings\job_listings_20241021.json.
# No job postings found on page 4. Stopping early.
# Data for 20241009 saved to job_listings\job_listings_20241009.json.
# No job postings found on page 4. Stopping early.
# Data for 20241007 saved to job_listings\job_listings_20241007.json.
# No job postings found on page 2. Stopping early.
# Data for 20241113 saved to job_listings\job_listings_20241113.json.
# No job postings found on page 4. Stopping early.
# Data for 20241017 saved to job_listings\job_listings_20241017.json.
# No job postings found on page 3. Stopping early.
# Data for 20241030 saved to job_listings\job_listings_20241030.json.
# No job postings found on page 2. Stopping early.
# Data for 20241108 saved to job_listings\job_listings_20241108.json.
# No job postings found on page 3. Stopping early.
# Data for 20241031 saved to job_listings\job_listings_20241031.json.
# No job postings found on page 4. Stopping early.
# Data for 20241010 saved to job_listings\job_listings_20241010.json.
# No job postings found on page 4. Stopping early.
# Data for 20241024 saved to job_listings\job_listings_20241024.json.
# No job postings found on page 4. Stopping early.
# Data for 20241023 saved to job_listings\job_listings_20241023.json.
# No job postings found on page 3. Stopping early.
# Data for 20241106 saved to job_listings\job_listings_20241106.json.
# No job postings found on page 5. Stopping early.
# Data for 20241002 saved to job_listings\job_listings_20241002.json.
# No job postings found on page 5. Stopping early.
# Data for 20241003 saved to job_listings\job_listings_20241003.json.
# No job postings found on page 2. Stopping early.
# Data for 20241111 saved to job_listings\job_listings_20241111.json.
# No job postings found on page 3. Stopping early.
# Data for 20241101 saved to job_listings\job_listings_20241101.json.
# No job postings found on page 5. Stopping early.
# Data for 20241008 saved to job_listings\job_listings_20241008.json.
# No job postings found on page 3. Stopping early.
# Data for 20241105 saved to job_listings\job_listings_20241105.json.
# No job postings found on page 5. Stopping early.
# Data for 20241011 saved to job_listings\job_listings_20241011.json.
# No job postings found on page 3. Stopping early.
# Data for 20241107 saved to job_listings\job_listings_20241107.json.
# No job postings found on page 4. Stopping early.
# Data for 20241025 saved to job_listings\job_listings_20241025.json.
# No job postings found on page 4. Stopping early.
# Data for 20241028 saved to job_listings\job_listings_20241028.json.
# No job postings found on page 5. Stopping early.
# Data for 20241004 saved to job_listings\job_listings_20241004.json.
# No job postings found on page 5. Stopping early.
# Data for 20241001 saved to job_listings\job_listings_20241001.json.
# All scraping tasks completed.
