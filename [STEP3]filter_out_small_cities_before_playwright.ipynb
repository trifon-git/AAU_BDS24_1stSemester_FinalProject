# %%
import os
import json
import re
import pandas as pd

# Define input and output folder paths
input_folder = "archive"  # Replace with the path to your folder containing the JSON files
output_folder = "archive_filtered"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to clean trailing indicators
def clean_trailing_indicators(area):
    if not area:
        return None
    # Remove trailing indicators like 'o', 'c', etc.
    area = re.sub(r'\s+[a-zA-ZÆØÅæøå]+$', '', area.strip())
    return area

# Function to keep the first meaningful city/place
def keep_first_place_simple(area):
    if not area:
        return None
    # Split by delimiters and keep the first part
    delimiters = [',', '/', ' og', ' eller', ' or', ' and']
    for delim in delimiters:
        if delim in area:
            area = area.split(delim)[0].strip()
            break
    return area if len(area) > 2 else None

# Danish to English city name mapping
city_name_mapping = {
    'København': 'Copenhagen',
    'Århus': 'Aarhus',
    'Helsingør': 'Elsinore'
}

# List of the 30 biggest cities in Denmark
biggest_cities = [
    "Copenhagen", "Aarhus", "Odense", "Aalborg", "Esbjerg", "Randers", "Kolding", "Horsens", "Vejle", "Roskilde",
    "Herning", "Hørsholm", "Silkeborg", "Næstved", "Fredericia", "Viborg", "Køge", "Holstebro", "Taastrup", "Slagelse",
    "Hillerød", "Sønderborg", "Svendborg", "Hjørring", "Holbæk", "Frederikshavn", "Nørresundby", "Ringsted", "Haderslev",
    "Skive", "Ølstykke-Stenløse", "Nykøbing Falster", "Greve Strand", "Kalundborg", "Ballerup", "Rødovre", "Lyngby",
    "Albertslund", "Hvidovre", "Glostrup", "Ishøj", "Birkerød", "Farum", "Frederikssund", "Brøndby Strand",
    "Skanderborg", "Hedensted", "Frederiksværk", "Lillerød", "Solrød Strand"
]

# Process each JSON file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".json"):
        input_file_path = os.path.join(input_folder, file_name)
        output_file_path = os.path.join(output_folder, file_name)
        
        # Read the JSON file
        print(f"Processing file: {file_name}")
        with open(input_file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        
        # Filter and clean jobs
        filtered_jobs = []
        for job in data:
            area = job.get("Area")
            if area:
                # Apply cleaning functions
                area = clean_trailing_indicators(area)
                area = keep_first_place_simple(area)
                area = city_name_mapping.get(area, area)  # Map to English names
                # Check if the cleaned area is in the list of biggest cities
                if area in biggest_cities:
                    job["Area"] = area  # Update area in the job record
                    filtered_jobs.append(job)
        
        # Feedback on the number of jobs retained
        print(f"File: {file_name} | Original jobs: {len(data)} | Filtered jobs: {len(filtered_jobs)}")
        
        # Write the filtered jobs to a new JSON file
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            json.dump(filtered_jobs, output_file, ensure_ascii=False, indent=4)

print(f"All files have been processed. Filtered files are saved in the '{output_folder}' directory.")
# Out:
# Processing file: job_listings_20160101_archive.json
# File: job_listings_20160101_archive.json | Original jobs: 19 | Filtered jobs: 15
# Processing file: job_listings_20160102_archive.json
# File: job_listings_20160102_archive.json | Original jobs: 4 | Filtered jobs: 3
# Processing file: job_listings_20160103_archive.json
# File: job_listings_20160103_archive.json | Original jobs: 7 | Filtered jobs: 7
# Processing file: job_listings_20160104_archive.json
# File: job_listings_20160104_archive.json | Original jobs: 60 | Filtered jobs: 31
# Processing file: job_listings_20160105_archive.json
# File: job_listings_20160105_archive.json | Original jobs: 96 | Filtered jobs: 53
# Processing file: job_listings_20160106_archive.json
# File: job_listings_20160106_archive.json | Original jobs: 61 | Filtered jobs: 28
# Processing file: job_listings_20160107_archive.json
# File: job_listings_20160107_archive.json | Original jobs: 53 | Filtered jobs: 30
# Processing file: job_listings_20160108_archive.json
# File: job_listings_20160108_archive.json | Original jobs: 89 | Filtered jobs: 48
# Processing file: job_listings_20160109_archive.json
# File: job_listings_20160109_archive.json | Original jobs: 20 | Filtered jobs: 17
# Processing file: job_listings_20160110_archive.json
# File: job_listings_20160110_archive.json | Original jobs: 11 | Filtered jobs: 10
# Processing file: job_listings_20160111_archive.json
# File: job_listings_20160111_archive.json | Original jobs: 72 | Filtered jobs: 39
# Processing file: job_listings_20160112_archive.json
# File: job_listings_20160112_archive.json | Original jobs: 71 | Filtered jobs: 46
# Processing file: job_listings_20160113_archive.json
# File: job_listings_20160113_archive.json | Original jobs: 71 | Filtered jobs: 34
# Processing file: job_listings_20160114_archive.json
# File: job_listings_20160114_archive.json | Original jobs: 88 | Filtered jobs: 50
# Processing file: job_listings_20160115_archive.json
# File: job_listings_20160115_archive.json | Original jobs: 68 | Filtered jobs: 31
# Processing file: job_listings_20160116_archive.json
# File: job_listings_20160116_archive.json | Original jobs: 30 | Filtered jobs: 22
# Processing file: job_listings_20160117_archive.json
# File: job_listings_20160117_archive.json | Original jobs: 6 | Filtered jobs: 5
# Processing file: job_listings_20160118_archive.json
# File: job_listings_20160118_archive.json | Original jobs: 76 | Filtered jobs: 40
# Processing file: job_listings_20160119_archive.json
# File: job_listings_20160119_archive.json | Original jobs: 56 | Filtered jobs: 30
# Processing file: job_listings_20160120_archive.json
# File: job_listings_20160120_archive.json | Original jobs: 74 | Filtered jobs: 44
# Processing file: job_listings_20160121_archive.json
# File: job_listings_20160121_archive.json | Original jobs: 68 | Filtered jobs: 32
# Processing file: job_listings_20160122_archive.json
# File: job_listings_20160122_archive.json | Original jobs: 163 | Filtered jobs: 73
# Processing file: job_listings_20160123_archive.json
# File: job_listings_20160123_archive.json | Original jobs: 13 | Filtered jobs: 9
# Processing file: job_listings_20160124_archive.json
# File: job_listings_20160124_archive.json | Original jobs: 23 | Filtered jobs: 16
# Processing file: job_listings_20160125_archive.json
# File: job_listings_20160125_archive.json | Original jobs: 65 | Filtered jobs: 30
# Processing file: job_listings_20160126_archive.json
# File: job_listings_20160126_archive.json | Original jobs: 60 | Filtered jobs: 37
# Processing file: job_listings_20160127_archive.json
# File: job_listings_20160127_archive.json | Original jobs: 60 | Filtered jobs: 32
# Processing file: job_listings_20160128_archive.json
# File: job_listings_20160128_archive.json | Original jobs: 85 | Filtered jobs: 53
# Processing file: job_listings_20160129_archive.json
# File: job_listings_20160129_archive.json | Original jobs: 58 | Filtered jobs: 32
# Processing file: job_listings_20160130_archive.json
# File: job_listings_20160130_archive.json | Original jobs: 17 | Filtered jobs: 11
# Processing file: job_listings_20160131_archive.json
# File: job_listings_20160131_archive.json | Original jobs: 3 | Filtered jobs: 2
# Processing file: job_listings_20160201_archive.json
# File: job_listings_20160201_archive.json | Original jobs: 74 | Filtered jobs: 36
# Processing file: job_listings_20160202_archive.json
# File: job_listings_20160202_archive.json | Original jobs: 80 | Filtered jobs: 36
# Processing file: job_listings_20160203_archive.json
# File: job_listings_20160203_archive.json | Original jobs: 72 | Filtered jobs: 32
# Processing file: job_listings_20160204_archive.json
# File: job_listings_20160204_archive.json | Original jobs: 63 | Filtered jobs: 34
# Processing file: job_listings_20160205_archive.json
# File: job_listings_20160205_archive.json | Original jobs: 70 | Filtered jobs: 35
# Processing file: job_listings_20160206_archive.json
# File: job_listings_20160206_archive.json | Original jobs: 21 | Filtered jobs: 16
# Processing file: job_listings_20160207_archive.json
# File: job_listings_20160207_archive.json | Original jobs: 8 | Filtered jobs: 5
# Processing file: job_listings_20160208_archive.json
# File: job_listings_20160208_archive.json | Original jobs: 73 | Filtered jobs: 40
# Processing file: job_listings_20160209_archive.json
# File: job_listings_20160209_archive.json | Original jobs: 76 | Filtered jobs: 44
# Processing file: job_listings_20160210_archive.json
# File: job_listings_20160210_archive.json | Original jobs: 56 | Filtered jobs: 35
# Processing file: job_listings_20160211_archive.json
# File: job_listings_20160211_archive.json | Original jobs: 77 | Filtered jobs: 37
# Processing file: job_listings_20160212_archive.json
# File: job_listings_20160212_archive.json | Original jobs: 62 | Filtered jobs: 35
# Processing file: job_listings_20160213_archive.json
# File: job_listings_20160213_archive.json | Original jobs: 7 | Filtered jobs: 3
# Processing file: job_listings_20160214_archive.json
# File: job_listings_20160214_archive.json | Original jobs: 9 | Filtered jobs: 6
# Processing file: job_listings_20160215_archive.json
# File: job_listings_20160215_archive.json | Original jobs: 71 | Filtered jobs: 30
# Processing file: job_listings_20160216_archive.json
# File: job_listings_20160216_archive.json | Original jobs: 74 | Filtered jobs: 42
# Processing file: job_listings_20160217_archive.json
# File: job_listings_20160217_archive.json | Original jobs: 68 | Filtered jobs: 38
# Processing file: job_listings_20160218_archive.json
# File: job_listings_20160218_archive.json | Original jobs: 73 | Filtered jobs: 39
# Processing file: job_listings_20160219_archive.json
# File: job_listings_20160219_archive.json | Original jobs: 65 | Filtered jobs: 35
# Processing file: job_listings_20160220_archive.json
# File: job_listings_20160220_archive.json | Original jobs: 7 | Filtered jobs: 4
# Processing file: job_listings_20160221_archive.json
# File: job_listings_20160221_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20160222_archive.json
# File: job_listings_20160222_archive.json | Original jobs: 86 | Filtered jobs: 43
# Processing file: job_listings_20160223_archive.json
# File: job_listings_20160223_archive.json | Original jobs: 67 | Filtered jobs: 40
# Processing file: job_listings_20160224_archive.json
# File: job_listings_20160224_archive.json | Original jobs: 71 | Filtered jobs: 45
# Processing file: job_listings_20160225_archive.json
# File: job_listings_20160225_archive.json | Original jobs: 65 | Filtered jobs: 28
# Processing file: job_listings_20160226_archive.json
# File: job_listings_20160226_archive.json | Original jobs: 83 | Filtered jobs: 53
# Processing file: job_listings_20160227_archive.json
# File: job_listings_20160227_archive.json | Original jobs: 12 | Filtered jobs: 11
# Processing file: job_listings_20160228_archive.json
# File: job_listings_20160228_archive.json | Original jobs: 16 | Filtered jobs: 7
# Processing file: job_listings_20160229_archive.json
# File: job_listings_20160229_archive.json | Original jobs: 74 | Filtered jobs: 38
# Processing file: job_listings_20160301_archive.json
# File: job_listings_20160301_archive.json | Original jobs: 61 | Filtered jobs: 36
# Processing file: job_listings_20160302_archive.json
# File: job_listings_20160302_archive.json | Original jobs: 70 | Filtered jobs: 44
# Processing file: job_listings_20160303_archive.json
# File: job_listings_20160303_archive.json | Original jobs: 61 | Filtered jobs: 40
# Processing file: job_listings_20160304_archive.json
# File: job_listings_20160304_archive.json | Original jobs: 71 | Filtered jobs: 39
# Processing file: job_listings_20160305_archive.json
# File: job_listings_20160305_archive.json | Original jobs: 12 | Filtered jobs: 6
# Processing file: job_listings_20160306_archive.json
# File: job_listings_20160306_archive.json | Original jobs: 6 | Filtered jobs: 2
# Processing file: job_listings_20160307_archive.json
# File: job_listings_20160307_archive.json | Original jobs: 92 | Filtered jobs: 55
# Processing file: job_listings_20160308_archive.json
# File: job_listings_20160308_archive.json | Original jobs: 72 | Filtered jobs: 41
# Processing file: job_listings_20160309_archive.json
# File: job_listings_20160309_archive.json | Original jobs: 60 | Filtered jobs: 36
# Processing file: job_listings_20160310_archive.json
# File: job_listings_20160310_archive.json | Original jobs: 81 | Filtered jobs: 48
# Processing file: job_listings_20160311_archive.json
# File: job_listings_20160311_archive.json | Original jobs: 81 | Filtered jobs: 46
# Processing file: job_listings_20160312_archive.json
# File: job_listings_20160312_archive.json | Original jobs: 13 | Filtered jobs: 10
# Processing file: job_listings_20160313_archive.json
# File: job_listings_20160313_archive.json | Original jobs: 5 | Filtered jobs: 3
# Processing file: job_listings_20160314_archive.json
# File: job_listings_20160314_archive.json | Original jobs: 151 | Filtered jobs: 80
# Processing file: job_listings_20160315_archive.json
# File: job_listings_20160315_archive.json | Original jobs: 60 | Filtered jobs: 34
# Processing file: job_listings_20160316_archive.json
# File: job_listings_20160316_archive.json | Original jobs: 80 | Filtered jobs: 52
# Processing file: job_listings_20160317_archive.json
# File: job_listings_20160317_archive.json | Original jobs: 87 | Filtered jobs: 53
# Processing file: job_listings_20160318_archive.json
# File: job_listings_20160318_archive.json | Original jobs: 83 | Filtered jobs: 48
# Processing file: job_listings_20160319_archive.json
# File: job_listings_20160319_archive.json | Original jobs: 12 | Filtered jobs: 7
# Processing file: job_listings_20160320_archive.json
# File: job_listings_20160320_archive.json | Original jobs: 9 | Filtered jobs: 7
# Processing file: job_listings_20160321_archive.json
# File: job_listings_20160321_archive.json | Original jobs: 79 | Filtered jobs: 50
# Processing file: job_listings_20160322_archive.json
# File: job_listings_20160322_archive.json | Original jobs: 64 | Filtered jobs: 41
# Processing file: job_listings_20160323_archive.json
# File: job_listings_20160323_archive.json | Original jobs: 51 | Filtered jobs: 23
# Processing file: job_listings_20160324_archive.json
# File: job_listings_20160324_archive.json | Original jobs: 19 | Filtered jobs: 13
# Processing file: job_listings_20160325_archive.json
# File: job_listings_20160325_archive.json | Original jobs: 8 | Filtered jobs: 7
# Processing file: job_listings_20160326_archive.json
# File: job_listings_20160326_archive.json | Original jobs: 5 | Filtered jobs: 3
# Processing file: job_listings_20160327_archive.json
# File: job_listings_20160327_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20160328_archive.json
# File: job_listings_20160328_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20160329_archive.json
# File: job_listings_20160329_archive.json | Original jobs: 59 | Filtered jobs: 41
# Processing file: job_listings_20160330_archive.json
# File: job_listings_20160330_archive.json | Original jobs: 73 | Filtered jobs: 42
# Processing file: job_listings_20160331_archive.json
# File: job_listings_20160331_archive.json | Original jobs: 64 | Filtered jobs: 39
# Processing file: job_listings_20160401_archive.json
# File: job_listings_20160401_archive.json | Original jobs: 68 | Filtered jobs: 27
# Processing file: job_listings_20160402_archive.json
# File: job_listings_20160402_archive.json | Original jobs: 5 | Filtered jobs: 4
# Processing file: job_listings_20160403_archive.json
# File: job_listings_20160403_archive.json | Original jobs: 6 | Filtered jobs: 4
# Processing file: job_listings_20160404_archive.json
# File: job_listings_20160404_archive.json | Original jobs: 65 | Filtered jobs: 40
# Processing file: job_listings_20160405_archive.json
# File: job_listings_20160405_archive.json | Original jobs: 78 | Filtered jobs: 37
# Processing file: job_listings_20160406_archive.json
# File: job_listings_20160406_archive.json | Original jobs: 69 | Filtered jobs: 40
# Processing file: job_listings_20160407_archive.json
# File: job_listings_20160407_archive.json | Original jobs: 65 | Filtered jobs: 40
# Processing file: job_listings_20160408_archive.json
# File: job_listings_20160408_archive.json | Original jobs: 74 | Filtered jobs: 39
# Processing file: job_listings_20160409_archive.json
# File: job_listings_20160409_archive.json | Original jobs: 11 | Filtered jobs: 7
# Processing file: job_listings_20160410_archive.json
# File: job_listings_20160410_archive.json | Original jobs: 5 | Filtered jobs: 3
# Processing file: job_listings_20160411_archive.json
# File: job_listings_20160411_archive.json | Original jobs: 80 | Filtered jobs: 52
# Processing file: job_listings_20160412_archive.json
# File: job_listings_20160412_archive.json | Original jobs: 78 | Filtered jobs: 42
# Processing file: job_listings_20160413_archive.json
# File: job_listings_20160413_archive.json | Original jobs: 44 | Filtered jobs: 21
# Processing file: job_listings_20160414_archive.json
# File: job_listings_20160414_archive.json | Original jobs: 73 | Filtered jobs: 44
# Processing file: job_listings_20160415_archive.json
# File: job_listings_20160415_archive.json | Original jobs: 81 | Filtered jobs: 51
# Processing file: job_listings_20160416_archive.json
# File: job_listings_20160416_archive.json | Original jobs: 13 | Filtered jobs: 7
# Processing file: job_listings_20160418_archive.json
# File: job_listings_20160418_archive.json | Original jobs: 61 | Filtered jobs: 34
# Processing file: job_listings_20160419_archive.json
# File: job_listings_20160419_archive.json | Original jobs: 76 | Filtered jobs: 49
# Processing file: job_listings_20160420_archive.json
# File: job_listings_20160420_archive.json | Original jobs: 78 | Filtered jobs: 43
# Processing file: job_listings_20160421_archive.json
# File: job_listings_20160421_archive.json | Original jobs: 104 | Filtered jobs: 42
# Processing file: job_listings_20160422_archive.json
# File: job_listings_20160422_archive.json | Original jobs: 14 | Filtered jobs: 10
# Processing file: job_listings_20160423_archive.json
# File: job_listings_20160423_archive.json | Original jobs: 7 | Filtered jobs: 2
# Processing file: job_listings_20160424_archive.json
# File: job_listings_20160424_archive.json | Original jobs: 3 | Filtered jobs: 2
# Processing file: job_listings_20160425_archive.json
# File: job_listings_20160425_archive.json | Original jobs: 77 | Filtered jobs: 35
# Processing file: job_listings_20160426_archive.json
# File: job_listings_20160426_archive.json | Original jobs: 43 | Filtered jobs: 20
# Processing file: job_listings_20160427_archive.json
# File: job_listings_20160427_archive.json | Original jobs: 87 | Filtered jobs: 49
# Processing file: job_listings_20160428_archive.json
# File: job_listings_20160428_archive.json | Original jobs: 78 | Filtered jobs: 48
# Processing file: job_listings_20160429_archive.json
# File: job_listings_20160429_archive.json | Original jobs: 91 | Filtered jobs: 56
# Processing file: job_listings_20160430_archive.json
# File: job_listings_20160430_archive.json | Original jobs: 9 | Filtered jobs: 8
# Processing file: job_listings_20160501_archive.json
# File: job_listings_20160501_archive.json | Original jobs: 6 | Filtered jobs: 2
# Processing file: job_listings_20160502_archive.json
# File: job_listings_20160502_archive.json | Original jobs: 59 | Filtered jobs: 33
# Processing file: job_listings_20160503_archive.json
# File: job_listings_20160503_archive.json | Original jobs: 94 | Filtered jobs: 54
# Processing file: job_listings_20160504_archive.json
# File: job_listings_20160504_archive.json | Original jobs: 105 | Filtered jobs: 52
# Processing file: job_listings_20160505_archive.json
# File: job_listings_20160505_archive.json | Original jobs: 30 | Filtered jobs: 21
# Processing file: job_listings_20160506_archive.json
# File: job_listings_20160506_archive.json | Original jobs: 44 | Filtered jobs: 18
# Processing file: job_listings_20160507_archive.json
# File: job_listings_20160507_archive.json | Original jobs: 6 | Filtered jobs: 4
# Processing file: job_listings_20160508_archive.json
# File: job_listings_20160508_archive.json | Original jobs: 3 | Filtered jobs: 0
# Processing file: job_listings_20160509_archive.json
# File: job_listings_20160509_archive.json | Original jobs: 53 | Filtered jobs: 36
# Processing file: job_listings_20160510_archive.json
# File: job_listings_20160510_archive.json | Original jobs: 60 | Filtered jobs: 34
# Processing file: job_listings_20160511_archive.json
# File: job_listings_20160511_archive.json | Original jobs: 60 | Filtered jobs: 36
# Processing file: job_listings_20160512_archive.json
# File: job_listings_20160512_archive.json | Original jobs: 55 | Filtered jobs: 36
# Processing file: job_listings_20160513_archive.json
# File: job_listings_20160513_archive.json | Original jobs: 81 | Filtered jobs: 41
# Processing file: job_listings_20160514_archive.json
# File: job_listings_20160514_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20160515_archive.json
# File: job_listings_20160515_archive.json | Original jobs: 5 | Filtered jobs: 2
# Processing file: job_listings_20160516_archive.json
# File: job_listings_20160516_archive.json | Original jobs: 10 | Filtered jobs: 8
# Processing file: job_listings_20160517_archive.json
# File: job_listings_20160517_archive.json | Original jobs: 71 | Filtered jobs: 41
# Processing file: job_listings_20160518_archive.json
# File: job_listings_20160518_archive.json | Original jobs: 81 | Filtered jobs: 52
# Processing file: job_listings_20160519_archive.json
# File: job_listings_20160519_archive.json | Original jobs: 86 | Filtered jobs: 44
# Processing file: job_listings_20160520_archive.json
# File: job_listings_20160520_archive.json | Original jobs: 84 | Filtered jobs: 53
# Processing file: job_listings_20160521_archive.json
# File: job_listings_20160521_archive.json | Original jobs: 14 | Filtered jobs: 11
# Processing file: job_listings_20160522_archive.json
# File: job_listings_20160522_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20160523_archive.json
# File: job_listings_20160523_archive.json | Original jobs: 86 | Filtered jobs: 45
# Processing file: job_listings_20160524_archive.json
# File: job_listings_20160524_archive.json | Original jobs: 61 | Filtered jobs: 41
# Processing file: job_listings_20160525_archive.json
# File: job_listings_20160525_archive.json | Original jobs: 92 | Filtered jobs: 46
# Processing file: job_listings_20160526_archive.json
# File: job_listings_20160526_archive.json | Original jobs: 108 | Filtered jobs: 59
# Processing file: job_listings_20160527_archive.json
# File: job_listings_20160527_archive.json | Original jobs: 61 | Filtered jobs: 37
# Processing file: job_listings_20160528_archive.json
# File: job_listings_20160528_archive.json | Original jobs: 17 | Filtered jobs: 12
# Processing file: job_listings_20160529_archive.json
# File: job_listings_20160529_archive.json | Original jobs: 3 | Filtered jobs: 3
# Processing file: job_listings_20160530_archive.json
# File: job_listings_20160530_archive.json | Original jobs: 75 | Filtered jobs: 33
# Processing file: job_listings_20160531_archive.json
# File: job_listings_20160531_archive.json | Original jobs: 55 | Filtered jobs: 29
# Processing file: job_listings_20160601_archive.json
# File: job_listings_20160601_archive.json | Original jobs: 84 | Filtered jobs: 34
# Processing file: job_listings_20160602_archive.json
# File: job_listings_20160602_archive.json | Original jobs: 65 | Filtered jobs: 33
# Processing file: job_listings_20160603_archive.json
# File: job_listings_20160603_archive.json | Original jobs: 57 | Filtered jobs: 32
# Processing file: job_listings_20160604_archive.json
# File: job_listings_20160604_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20160605_archive.json
# File: job_listings_20160605_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20160606_archive.json
# File: job_listings_20160606_archive.json | Original jobs: 100 | Filtered jobs: 57
# Processing file: job_listings_20160607_archive.json
# File: job_listings_20160607_archive.json | Original jobs: 86 | Filtered jobs: 54
# Processing file: job_listings_20160608_archive.json
# File: job_listings_20160608_archive.json | Original jobs: 55 | Filtered jobs: 33
# Processing file: job_listings_20160609_archive.json
# File: job_listings_20160609_archive.json | Original jobs: 177 | Filtered jobs: 104
# Processing file: job_listings_20160610_archive.json
# File: job_listings_20160610_archive.json | Original jobs: 68 | Filtered jobs: 39
# Processing file: job_listings_20160611_archive.json
# File: job_listings_20160611_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20160613_archive.json
# File: job_listings_20160613_archive.json | Original jobs: 78 | Filtered jobs: 47
# Processing file: job_listings_20160614_archive.json
# File: job_listings_20160614_archive.json | Original jobs: 70 | Filtered jobs: 42
# Processing file: job_listings_20160615_archive.json
# File: job_listings_20160615_archive.json | Original jobs: 49 | Filtered jobs: 25
# Processing file: job_listings_20160616_archive.json
# File: job_listings_20160616_archive.json | Original jobs: 55 | Filtered jobs: 33
# Processing file: job_listings_20160617_archive.json
# File: job_listings_20160617_archive.json | Original jobs: 62 | Filtered jobs: 24
# Processing file: job_listings_20160618_archive.json
# File: job_listings_20160618_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20160620_archive.json
# File: job_listings_20160620_archive.json | Original jobs: 84 | Filtered jobs: 51
# Processing file: job_listings_20160621_archive.json
# File: job_listings_20160621_archive.json | Original jobs: 65 | Filtered jobs: 37
# Processing file: job_listings_20160622_archive.json
# File: job_listings_20160622_archive.json | Original jobs: 54 | Filtered jobs: 30
# Processing file: job_listings_20160623_archive.json
# File: job_listings_20160623_archive.json | Original jobs: 63 | Filtered jobs: 26
# Processing file: job_listings_20160624_archive.json
# File: job_listings_20160624_archive.json | Original jobs: 59 | Filtered jobs: 39
# Processing file: job_listings_20160625_archive.json
# File: job_listings_20160625_archive.json | Original jobs: 6 | Filtered jobs: 6
# Processing file: job_listings_20160627_archive.json
# File: job_listings_20160627_archive.json | Original jobs: 61 | Filtered jobs: 40
# Processing file: job_listings_20160628_archive.json
# File: job_listings_20160628_archive.json | Original jobs: 59 | Filtered jobs: 32
# Processing file: job_listings_20160629_archive.json
# File: job_listings_20160629_archive.json | Original jobs: 66 | Filtered jobs: 45
# Processing file: job_listings_20160630_archive.json
# File: job_listings_20160630_archive.json | Original jobs: 57 | Filtered jobs: 34
# Processing file: job_listings_20160701_archive.json
# File: job_listings_20160701_archive.json | Original jobs: 76 | Filtered jobs: 47
# Processing file: job_listings_20160702_archive.json
# File: job_listings_20160702_archive.json | Original jobs: 12 | Filtered jobs: 11
# Processing file: job_listings_20160703_archive.json
# File: job_listings_20160703_archive.json | Original jobs: 4 | Filtered jobs: 3
# Processing file: job_listings_20160704_archive.json
# File: job_listings_20160704_archive.json | Original jobs: 69 | Filtered jobs: 33
# Processing file: job_listings_20160705_archive.json
# File: job_listings_20160705_archive.json | Original jobs: 81 | Filtered jobs: 55
# Processing file: job_listings_20160706_archive.json
# File: job_listings_20160706_archive.json | Original jobs: 74 | Filtered jobs: 39
# Processing file: job_listings_20160707_archive.json
# File: job_listings_20160707_archive.json | Original jobs: 60 | Filtered jobs: 36
# Processing file: job_listings_20160708_archive.json
# File: job_listings_20160708_archive.json | Original jobs: 103 | Filtered jobs: 63
# Processing file: job_listings_20160709_archive.json
# File: job_listings_20160709_archive.json | Original jobs: 11 | Filtered jobs: 9
# Processing file: job_listings_20160710_archive.json
# File: job_listings_20160710_archive.json | Original jobs: 12 | Filtered jobs: 11
# Processing file: job_listings_20160711_archive.json
# File: job_listings_20160711_archive.json | Original jobs: 74 | Filtered jobs: 35
# Processing file: job_listings_20160712_archive.json
# File: job_listings_20160712_archive.json | Original jobs: 64 | Filtered jobs: 36
# Processing file: job_listings_20160713_archive.json
# File: job_listings_20160713_archive.json | Original jobs: 54 | Filtered jobs: 29
# Processing file: job_listings_20160714_archive.json
# File: job_listings_20160714_archive.json | Original jobs: 92 | Filtered jobs: 47
# Processing file: job_listings_20160715_archive.json
# File: job_listings_20160715_archive.json | Original jobs: 65 | Filtered jobs: 48
# Processing file: job_listings_20160716_archive.json
# File: job_listings_20160716_archive.json | Original jobs: 16 | Filtered jobs: 9
# Processing file: job_listings_20160717_archive.json
# File: job_listings_20160717_archive.json | Original jobs: 8 | Filtered jobs: 5
# Processing file: job_listings_20160718_archive.json
# File: job_listings_20160718_archive.json | Original jobs: 71 | Filtered jobs: 43
# Processing file: job_listings_20160719_archive.json
# File: job_listings_20160719_archive.json | Original jobs: 69 | Filtered jobs: 37
# Processing file: job_listings_20160720_archive.json
# File: job_listings_20160720_archive.json | Original jobs: 48 | Filtered jobs: 28
# Processing file: job_listings_20160721_archive.json
# File: job_listings_20160721_archive.json | Original jobs: 42 | Filtered jobs: 21
# Processing file: job_listings_20160722_archive.json
# File: job_listings_20160722_archive.json | Original jobs: 47 | Filtered jobs: 26
# Processing file: job_listings_20160723_archive.json
# File: job_listings_20160723_archive.json | Original jobs: 6 | Filtered jobs: 5
# Processing file: job_listings_20160724_archive.json
# File: job_listings_20160724_archive.json | Original jobs: 9 | Filtered jobs: 9
# Processing file: job_listings_20160725_archive.json
# File: job_listings_20160725_archive.json | Original jobs: 59 | Filtered jobs: 34
# Processing file: job_listings_20160726_archive.json
# File: job_listings_20160726_archive.json | Original jobs: 35 | Filtered jobs: 15
# Processing file: job_listings_20160727_archive.json
# File: job_listings_20160727_archive.json | Original jobs: 34 | Filtered jobs: 18
# Processing file: job_listings_20160728_archive.json
# File: job_listings_20160728_archive.json | Original jobs: 40 | Filtered jobs: 24
# Processing file: job_listings_20160729_archive.json
# File: job_listings_20160729_archive.json | Original jobs: 52 | Filtered jobs: 38
# Processing file: job_listings_20160730_archive.json
# File: job_listings_20160730_archive.json | Original jobs: 7 | Filtered jobs: 5
# Processing file: job_listings_20160731_archive.json
# File: job_listings_20160731_archive.json | Original jobs: 7 | Filtered jobs: 4
# Processing file: job_listings_20160801_archive.json
# File: job_listings_20160801_archive.json | Original jobs: 57 | Filtered jobs: 34
# Processing file: job_listings_20160802_archive.json
# File: job_listings_20160802_archive.json | Original jobs: 54 | Filtered jobs: 25
# Processing file: job_listings_20160803_archive.json
# File: job_listings_20160803_archive.json | Original jobs: 41 | Filtered jobs: 24
# Processing file: job_listings_20160804_archive.json
# File: job_listings_20160804_archive.json | Original jobs: 61 | Filtered jobs: 35
# Processing file: job_listings_20160805_archive.json
# File: job_listings_20160805_archive.json | Original jobs: 44 | Filtered jobs: 24
# Processing file: job_listings_20160806_archive.json
# File: job_listings_20160806_archive.json | Original jobs: 2 | Filtered jobs: 0
# Processing file: job_listings_20160807_archive.json
# File: job_listings_20160807_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20160808_archive.json
# File: job_listings_20160808_archive.json | Original jobs: 74 | Filtered jobs: 42
# Processing file: job_listings_20160809_archive.json
# File: job_listings_20160809_archive.json | Original jobs: 59 | Filtered jobs: 34
# Processing file: job_listings_20160810_archive.json
# File: job_listings_20160810_archive.json | Original jobs: 68 | Filtered jobs: 48
# Processing file: job_listings_20160811_archive.json
# File: job_listings_20160811_archive.json | Original jobs: 74 | Filtered jobs: 39
# Processing file: job_listings_20160812_archive.json
# File: job_listings_20160812_archive.json | Original jobs: 69 | Filtered jobs: 32
# Processing file: job_listings_20160813_archive.json
# File: job_listings_20160813_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20160814_archive.json
# File: job_listings_20160814_archive.json | Original jobs: 3 | Filtered jobs: 1
# Processing file: job_listings_20160815_archive.json
# File: job_listings_20160815_archive.json | Original jobs: 65 | Filtered jobs: 34
# Processing file: job_listings_20160816_archive.json
# File: job_listings_20160816_archive.json | Original jobs: 70 | Filtered jobs: 41
# Processing file: job_listings_20160817_archive.json
# File: job_listings_20160817_archive.json | Original jobs: 58 | Filtered jobs: 35
# Processing file: job_listings_20160818_archive.json
# File: job_listings_20160818_archive.json | Original jobs: 55 | Filtered jobs: 24
# Processing file: job_listings_20160819_archive.json
# File: job_listings_20160819_archive.json | Original jobs: 79 | Filtered jobs: 45
# Processing file: job_listings_20160820_archive.json
# File: job_listings_20160820_archive.json | Original jobs: 5 | Filtered jobs: 4
# Processing file: job_listings_20160821_archive.json
# File: job_listings_20160821_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20160822_archive.json
# File: job_listings_20160822_archive.json | Original jobs: 61 | Filtered jobs: 33
# Processing file: job_listings_20160823_archive.json
# File: job_listings_20160823_archive.json | Original jobs: 59 | Filtered jobs: 35
# Processing file: job_listings_20160824_archive.json
# File: job_listings_20160824_archive.json | Original jobs: 42 | Filtered jobs: 18
# Processing file: job_listings_20160825_archive.json
# File: job_listings_20160825_archive.json | Original jobs: 63 | Filtered jobs: 39
# Processing file: job_listings_20160826_archive.json
# File: job_listings_20160826_archive.json | Original jobs: 55 | Filtered jobs: 36
# Processing file: job_listings_20160829_archive.json
# File: job_listings_20160829_archive.json | Original jobs: 67 | Filtered jobs: 33
# Processing file: job_listings_20160830_archive.json
# File: job_listings_20160830_archive.json | Original jobs: 71 | Filtered jobs: 31
# Processing file: job_listings_20160831_archive.json
# File: job_listings_20160831_archive.json | Original jobs: 67 | Filtered jobs: 38
# Processing file: job_listings_20160901_archive.json
# File: job_listings_20160901_archive.json | Original jobs: 65 | Filtered jobs: 35
# Processing file: job_listings_20160902_archive.json
# File: job_listings_20160902_archive.json | Original jobs: 70 | Filtered jobs: 39
# Processing file: job_listings_20160905_archive.json
# File: job_listings_20160905_archive.json | Original jobs: 73 | Filtered jobs: 44
# Processing file: job_listings_20160906_archive.json
# File: job_listings_20160906_archive.json | Original jobs: 74 | Filtered jobs: 48
# Processing file: job_listings_20160907_archive.json
# File: job_listings_20160907_archive.json | Original jobs: 79 | Filtered jobs: 46
# Processing file: job_listings_20160908_archive.json
# File: job_listings_20160908_archive.json | Original jobs: 85 | Filtered jobs: 33
# Processing file: job_listings_20160909_archive.json
# File: job_listings_20160909_archive.json | Original jobs: 70 | Filtered jobs: 41
# Processing file: job_listings_20160910_archive.json
# File: job_listings_20160910_archive.json | Original jobs: 4 | Filtered jobs: 0
# Processing file: job_listings_20160911_archive.json
# File: job_listings_20160911_archive.json | Original jobs: 2 | Filtered jobs: 0
# Processing file: job_listings_20160912_archive.json
# File: job_listings_20160912_archive.json | Original jobs: 69 | Filtered jobs: 43
# Processing file: job_listings_20160913_archive.json
# File: job_listings_20160913_archive.json | Original jobs: 176 | Filtered jobs: 99
# Processing file: job_listings_20160914_archive.json
# File: job_listings_20160914_archive.json | Original jobs: 66 | Filtered jobs: 38
# Processing file: job_listings_20160915_archive.json
# File: job_listings_20160915_archive.json | Original jobs: 168 | Filtered jobs: 85
# Processing file: job_listings_20160916_archive.json
# File: job_listings_20160916_archive.json | Original jobs: 61 | Filtered jobs: 38
# Processing file: job_listings_20160917_archive.json
# File: job_listings_20160917_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20160918_archive.json
# File: job_listings_20160918_archive.json | Original jobs: 11 | Filtered jobs: 7
# Processing file: job_listings_20160919_archive.json
# File: job_listings_20160919_archive.json | Original jobs: 84 | Filtered jobs: 59
# Processing file: job_listings_20160920_archive.json
# File: job_listings_20160920_archive.json | Original jobs: 95 | Filtered jobs: 71
# Processing file: job_listings_20160921_archive.json
# File: job_listings_20160921_archive.json | Original jobs: 52 | Filtered jobs: 23
# Processing file: job_listings_20160922_archive.json
# File: job_listings_20160922_archive.json | Original jobs: 73 | Filtered jobs: 45
# Processing file: job_listings_20160923_archive.json
# File: job_listings_20160923_archive.json | Original jobs: 80 | Filtered jobs: 49
# Processing file: job_listings_20160924_archive.json
# File: job_listings_20160924_archive.json | Original jobs: 3 | Filtered jobs: 1
# Processing file: job_listings_20160925_archive.json
# File: job_listings_20160925_archive.json | Original jobs: 3 | Filtered jobs: 0
# Processing file: job_listings_20160926_archive.json
# File: job_listings_20160926_archive.json | Original jobs: 66 | Filtered jobs: 39
# Processing file: job_listings_20160927_archive.json
# File: job_listings_20160927_archive.json | Original jobs: 60 | Filtered jobs: 33
# Processing file: job_listings_20160928_archive.json
# File: job_listings_20160928_archive.json | Original jobs: 71 | Filtered jobs: 43
# Processing file: job_listings_20160929_archive.json
# File: job_listings_20160929_archive.json | Original jobs: 107 | Filtered jobs: 65
# Processing file: job_listings_20160930_archive.json
# File: job_listings_20160930_archive.json | Original jobs: 66 | Filtered jobs: 44
# Processing file: job_listings_20161001_archive.json
# File: job_listings_20161001_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20161002_archive.json
# File: job_listings_20161002_archive.json | Original jobs: 2 | Filtered jobs: 0
# Processing file: job_listings_20161003_archive.json
# File: job_listings_20161003_archive.json | Original jobs: 80 | Filtered jobs: 45
# Processing file: job_listings_20161004_archive.json
# File: job_listings_20161004_archive.json | Original jobs: 71 | Filtered jobs: 46
# Processing file: job_listings_20161005_archive.json
# File: job_listings_20161005_archive.json | Original jobs: 65 | Filtered jobs: 35
# Processing file: job_listings_20161006_archive.json
# File: job_listings_20161006_archive.json | Original jobs: 71 | Filtered jobs: 42
# Processing file: job_listings_20161007_archive.json
# File: job_listings_20161007_archive.json | Original jobs: 78 | Filtered jobs: 50
# Processing file: job_listings_20161008_archive.json
# File: job_listings_20161008_archive.json | Original jobs: 6 | Filtered jobs: 2
# Processing file: job_listings_20161009_archive.json
# File: job_listings_20161009_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20161010_archive.json
# File: job_listings_20161010_archive.json | Original jobs: 87 | Filtered jobs: 53
# Processing file: job_listings_20161011_archive.json
# File: job_listings_20161011_archive.json | Original jobs: 73 | Filtered jobs: 31
# Processing file: job_listings_20161012_archive.json
# File: job_listings_20161012_archive.json | Original jobs: 71 | Filtered jobs: 41
# Processing file: job_listings_20161013_archive.json
# File: job_listings_20161013_archive.json | Original jobs: 65 | Filtered jobs: 28
# Processing file: job_listings_20161014_archive.json
# File: job_listings_20161014_archive.json | Original jobs: 76 | Filtered jobs: 37
# Processing file: job_listings_20161015_archive.json
# File: job_listings_20161015_archive.json | Original jobs: 4 | Filtered jobs: 0
# Processing file: job_listings_20161016_archive.json
# File: job_listings_20161016_archive.json | Original jobs: 3 | Filtered jobs: 3
# Processing file: job_listings_20161017_archive.json
# File: job_listings_20161017_archive.json | Original jobs: 86 | Filtered jobs: 48
# Processing file: job_listings_20161018_archive.json
# File: job_listings_20161018_archive.json | Original jobs: 61 | Filtered jobs: 37
# Processing file: job_listings_20161019_archive.json
# File: job_listings_20161019_archive.json | Original jobs: 62 | Filtered jobs: 42
# Processing file: job_listings_20161020_archive.json
# File: job_listings_20161020_archive.json | Original jobs: 46 | Filtered jobs: 19
# Processing file: job_listings_20161021_archive.json
# File: job_listings_20161021_archive.json | Original jobs: 48 | Filtered jobs: 33
# Processing file: job_listings_20161022_archive.json
# File: job_listings_20161022_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20161023_archive.json
# File: job_listings_20161023_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20161024_archive.json
# File: job_listings_20161024_archive.json | Original jobs: 77 | Filtered jobs: 41
# Processing file: job_listings_20161025_archive.json
# File: job_listings_20161025_archive.json | Original jobs: 65 | Filtered jobs: 41
# Processing file: job_listings_20161026_archive.json
# File: job_listings_20161026_archive.json | Original jobs: 45 | Filtered jobs: 31
# Processing file: job_listings_20161027_archive.json
# File: job_listings_20161027_archive.json | Original jobs: 56 | Filtered jobs: 30
# Processing file: job_listings_20161028_archive.json
# File: job_listings_20161028_archive.json | Original jobs: 44 | Filtered jobs: 22
# Processing file: job_listings_20161029_archive.json
# File: job_listings_20161029_archive.json | Original jobs: 2 | Filtered jobs: 0
# Processing file: job_listings_20161031_archive.json
# File: job_listings_20161031_archive.json | Original jobs: 71 | Filtered jobs: 43
# Processing file: job_listings_20161101_archive.json
# File: job_listings_20161101_archive.json | Original jobs: 68 | Filtered jobs: 42
# Processing file: job_listings_20161102_archive.json
# File: job_listings_20161102_archive.json | Original jobs: 64 | Filtered jobs: 38
# Processing file: job_listings_20161103_archive.json
# File: job_listings_20161103_archive.json | Original jobs: 97 | Filtered jobs: 58
# Processing file: job_listings_20161104_archive.json
# File: job_listings_20161104_archive.json | Original jobs: 80 | Filtered jobs: 47
# Processing file: job_listings_20161106_archive.json
# File: job_listings_20161106_archive.json | Original jobs: 3 | Filtered jobs: 3
# Processing file: job_listings_20161107_archive.json
# File: job_listings_20161107_archive.json | Original jobs: 90 | Filtered jobs: 49
# Processing file: job_listings_20161108_archive.json
# File: job_listings_20161108_archive.json | Original jobs: 86 | Filtered jobs: 40
# Processing file: job_listings_20161109_archive.json
# File: job_listings_20161109_archive.json | Original jobs: 66 | Filtered jobs: 40
# Processing file: job_listings_20161110_archive.json
# File: job_listings_20161110_archive.json | Original jobs: 56 | Filtered jobs: 35
# Processing file: job_listings_20161111_archive.json
# File: job_listings_20161111_archive.json | Original jobs: 66 | Filtered jobs: 44
# Processing file: job_listings_20161112_archive.json
# File: job_listings_20161112_archive.json | Original jobs: 9 | Filtered jobs: 4
# Processing file: job_listings_20161114_archive.json
# File: job_listings_20161114_archive.json | Original jobs: 85 | Filtered jobs: 50
# Processing file: job_listings_20161115_archive.json
# File: job_listings_20161115_archive.json | Original jobs: 54 | Filtered jobs: 28
# Processing file: job_listings_20161116_archive.json
# File: job_listings_20161116_archive.json | Original jobs: 94 | Filtered jobs: 38
# Processing file: job_listings_20161117_archive.json
# File: job_listings_20161117_archive.json | Original jobs: 66 | Filtered jobs: 36
# Processing file: job_listings_20161118_archive.json
# File: job_listings_20161118_archive.json | Original jobs: 67 | Filtered jobs: 46
# Processing file: job_listings_20161119_archive.json
# File: job_listings_20161119_archive.json | Original jobs: 2 | Filtered jobs: 0
# Processing file: job_listings_20161120_archive.json
# File: job_listings_20161120_archive.json | Original jobs: 5 | Filtered jobs: 5
# Processing file: job_listings_20161121_archive.json
# File: job_listings_20161121_archive.json | Original jobs: 53 | Filtered jobs: 31
# Processing file: job_listings_20161122_archive.json
# File: job_listings_20161122_archive.json | Original jobs: 68 | Filtered jobs: 36
# Processing file: job_listings_20161123_archive.json
# File: job_listings_20161123_archive.json | Original jobs: 70 | Filtered jobs: 42
# Processing file: job_listings_20161124_archive.json
# File: job_listings_20161124_archive.json | Original jobs: 49 | Filtered jobs: 31
# Processing file: job_listings_20161125_archive.json
# File: job_listings_20161125_archive.json | Original jobs: 57 | Filtered jobs: 38
# Processing file: job_listings_20161126_archive.json
# File: job_listings_20161126_archive.json | Original jobs: 5 | Filtered jobs: 2
# Processing file: job_listings_20161127_archive.json
# File: job_listings_20161127_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20161128_archive.json
# File: job_listings_20161128_archive.json | Original jobs: 60 | Filtered jobs: 28
# Processing file: job_listings_20161129_archive.json
# File: job_listings_20161129_archive.json | Original jobs: 45 | Filtered jobs: 24
# Processing file: job_listings_20161130_archive.json
# File: job_listings_20161130_archive.json | Original jobs: 49 | Filtered jobs: 26
# Processing file: job_listings_20161201_archive.json
# File: job_listings_20161201_archive.json | Original jobs: 53 | Filtered jobs: 27
# Processing file: job_listings_20161202_archive.json
# File: job_listings_20161202_archive.json | Original jobs: 91 | Filtered jobs: 38
# Processing file: job_listings_20161203_archive.json
# File: job_listings_20161203_archive.json | Original jobs: 5 | Filtered jobs: 0
# Processing file: job_listings_20161204_archive.json
# File: job_listings_20161204_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20161205_archive.json
# File: job_listings_20161205_archive.json | Original jobs: 84 | Filtered jobs: 40
# Processing file: job_listings_20161206_archive.json
# File: job_listings_20161206_archive.json | Original jobs: 64 | Filtered jobs: 35
# Processing file: job_listings_20161207_archive.json
# File: job_listings_20161207_archive.json | Original jobs: 78 | Filtered jobs: 45
# Processing file: job_listings_20161208_archive.json
# File: job_listings_20161208_archive.json | Original jobs: 62 | Filtered jobs: 36
# Processing file: job_listings_20161209_archive.json
# File: job_listings_20161209_archive.json | Original jobs: 59 | Filtered jobs: 24
# Processing file: job_listings_20161210_archive.json
# File: job_listings_20161210_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20161211_archive.json
# File: job_listings_20161211_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20161212_archive.json
# File: job_listings_20161212_archive.json | Original jobs: 56 | Filtered jobs: 30
# Processing file: job_listings_20161213_archive.json
# File: job_listings_20161213_archive.json | Original jobs: 76 | Filtered jobs: 23
# Processing file: job_listings_20161214_archive.json
# File: job_listings_20161214_archive.json | Original jobs: 71 | Filtered jobs: 31
# Processing file: job_listings_20161215_archive.json
# File: job_listings_20161215_archive.json | Original jobs: 72 | Filtered jobs: 38
# Processing file: job_listings_20161216_archive.json
# File: job_listings_20161216_archive.json | Original jobs: 68 | Filtered jobs: 36
# Processing file: job_listings_20161217_archive.json
# File: job_listings_20161217_archive.json | Original jobs: 3 | Filtered jobs: 2
# Processing file: job_listings_20161218_archive.json
# File: job_listings_20161218_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20161219_archive.json
# File: job_listings_20161219_archive.json | Original jobs: 79 | Filtered jobs: 45
# Processing file: job_listings_20161220_archive.json
# File: job_listings_20161220_archive.json | Original jobs: 75 | Filtered jobs: 44
# Processing file: job_listings_20161221_archive.json
# File: job_listings_20161221_archive.json | Original jobs: 129 | Filtered jobs: 74
# Processing file: job_listings_20161222_archive.json
# File: job_listings_20161222_archive.json | Original jobs: 131 | Filtered jobs: 71
# Processing file: job_listings_20161223_archive.json
# File: job_listings_20161223_archive.json | Original jobs: 114 | Filtered jobs: 60
# Processing file: job_listings_20161224_archive.json
# File: job_listings_20161224_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20161225_archive.json
# File: job_listings_20161225_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20161226_archive.json
# File: job_listings_20161226_archive.json | Original jobs: 13 | Filtered jobs: 7
# Processing file: job_listings_20161227_archive.json
# File: job_listings_20161227_archive.json | Original jobs: 38 | Filtered jobs: 23
# Processing file: job_listings_20161228_archive.json
# File: job_listings_20161228_archive.json | Original jobs: 34 | Filtered jobs: 21
# Processing file: job_listings_20161229_archive.json
# File: job_listings_20161229_archive.json | Original jobs: 30 | Filtered jobs: 19
# Processing file: job_listings_20161230_archive.json
# File: job_listings_20161230_archive.json | Original jobs: 23 | Filtered jobs: 12
# Processing file: job_listings_20170101_archive.json
# File: job_listings_20170101_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20170102_archive.json
# File: job_listings_20170102_archive.json | Original jobs: 49 | Filtered jobs: 18
# Processing file: job_listings_20170103_archive.json
# File: job_listings_20170103_archive.json | Original jobs: 86 | Filtered jobs: 52
# Processing file: job_listings_20170104_archive.json
# File: job_listings_20170104_archive.json | Original jobs: 69 | Filtered jobs: 30
# Processing file: job_listings_20170105_archive.json
# File: job_listings_20170105_archive.json | Original jobs: 77 | Filtered jobs: 40
# Processing file: job_listings_20170106_archive.json
# File: job_listings_20170106_archive.json | Original jobs: 74 | Filtered jobs: 41
# Processing file: job_listings_20170107_archive.json
# File: job_listings_20170107_archive.json | Original jobs: 4 | Filtered jobs: 0
# Processing file: job_listings_20170109_archive.json
# File: job_listings_20170109_archive.json | Original jobs: 78 | Filtered jobs: 42
# ...
# Processing file: job_listings_20240716_archive.json
# File: job_listings_20240716_archive.json | Original jobs: 32 | Filtered jobs: 23
# Processing file: job_listings_20240717_archive.json
# File: job_listings_20240717_archive.json | Original jobs: 43 | Filtered jobs: 27
# Processing file: job_listings_20240718_archive.json
# File: job_listings_20240718_archive.json | Original jobs: 30 | Filtered jobs: 18
# Processing file: job_listings_20240719_archive.json
# File: job_listings_20240719_archive.json | Original jobs: 31 | Filtered jobs: 24
# Processing file: job_listings_20240720_archive.json
# File: job_listings_20240720_archive.json | Original jobs: 9 | Filtered jobs: 7
# Processing file: job_listings_20240722_archive.json
# File: job_listings_20240722_archive.json | Original jobs: 41 | Filtered jobs: 24
# Processing file: job_listings_20240723_archive.json
# File: job_listings_20240723_archive.json | Original jobs: 36 | Filtered jobs: 23
# Processing file: job_listings_20240724_archive.json
# File: job_listings_20240724_archive.json | Original jobs: 26 | Filtered jobs: 17
# Processing file: job_listings_20240725_archive.json
# File: job_listings_20240725_archive.json | Original jobs: 39 | Filtered jobs: 27
# Processing file: job_listings_20240726_archive.json
# File: job_listings_20240726_archive.json | Original jobs: 42 | Filtered jobs: 28
# Processing file: job_listings_20240727_archive.json
# File: job_listings_20240727_archive.json | Original jobs: 5 | Filtered jobs: 3
# Processing file: job_listings_20240728_archive.json
# File: job_listings_20240728_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20240729_archive.json
# File: job_listings_20240729_archive.json | Original jobs: 63 | Filtered jobs: 32
# Processing file: job_listings_20240730_archive.json
# File: job_listings_20240730_archive.json | Original jobs: 44 | Filtered jobs: 26
# Processing file: job_listings_20240731_archive.json
# File: job_listings_20240731_archive.json | Original jobs: 33 | Filtered jobs: 22
# Processing file: job_listings_20240801_archive.json
# File: job_listings_20240801_archive.json | Original jobs: 55 | Filtered jobs: 35
# Processing file: job_listings_20240802_archive.json
# File: job_listings_20240802_archive.json | Original jobs: 57 | Filtered jobs: 37
# Processing file: job_listings_20240803_archive.json
# File: job_listings_20240803_archive.json | Original jobs: 8 | Filtered jobs: 5
# Processing file: job_listings_20240804_archive.json
# File: job_listings_20240804_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20240805_archive.json
# File: job_listings_20240805_archive.json | Original jobs: 71 | Filtered jobs: 50
# Processing file: job_listings_20240806_archive.json
# File: job_listings_20240806_archive.json | Original jobs: 67 | Filtered jobs: 40
# Processing file: job_listings_20240807_archive.json
# File: job_listings_20240807_archive.json | Original jobs: 66 | Filtered jobs: 47
# Processing file: job_listings_20240808_archive.json
# File: job_listings_20240808_archive.json | Original jobs: 51 | Filtered jobs: 28
# Processing file: job_listings_20240809_archive.json
# File: job_listings_20240809_archive.json | Original jobs: 51 | Filtered jobs: 23
# Processing file: job_listings_20240810_archive.json
# File: job_listings_20240810_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20240812_archive.json
# File: job_listings_20240812_archive.json | Original jobs: 57 | Filtered jobs: 33
# Processing file: job_listings_20240813_archive.json
# File: job_listings_20240813_archive.json | Original jobs: 59 | Filtered jobs: 40
# Processing file: job_listings_20240814_archive.json
# File: job_listings_20240814_archive.json | Original jobs: 60 | Filtered jobs: 34
# Processing file: job_listings_20240815_archive.json
# File: job_listings_20240815_archive.json | Original jobs: 54 | Filtered jobs: 37
# Processing file: job_listings_20240816_archive.json
# File: job_listings_20240816_archive.json | Original jobs: 55 | Filtered jobs: 31
# Processing file: job_listings_20240817_archive.json
# File: job_listings_20240817_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20240819_archive.json
# File: job_listings_20240819_archive.json | Original jobs: 63 | Filtered jobs: 37
# Processing file: job_listings_20240820_archive.json
# File: job_listings_20240820_archive.json | Original jobs: 74 | Filtered jobs: 49
# Processing file: job_listings_20240821_archive.json
# File: job_listings_20240821_archive.json | Original jobs: 56 | Filtered jobs: 38
# Processing file: job_listings_20240822_archive.json
# File: job_listings_20240822_archive.json | Original jobs: 53 | Filtered jobs: 30
# Processing file: job_listings_20240823_archive.json
# File: job_listings_20240823_archive.json | Original jobs: 59 | Filtered jobs: 34
# Processing file: job_listings_20240825_archive.json
# File: job_listings_20240825_archive.json | Original jobs: 3 | Filtered jobs: 2
# Processing file: job_listings_20240826_archive.json
# File: job_listings_20240826_archive.json | Original jobs: 43 | Filtered jobs: 21
# Processing file: job_listings_20240827_archive.json
# File: job_listings_20240827_archive.json | Original jobs: 45 | Filtered jobs: 32
# Processing file: job_listings_20240828_archive.json
# File: job_listings_20240828_archive.json | Original jobs: 48 | Filtered jobs: 30
# Processing file: job_listings_20240829_archive.json
# File: job_listings_20240829_archive.json | Original jobs: 53 | Filtered jobs: 35
# Processing file: job_listings_20240830_archive.json
# File: job_listings_20240830_archive.json | Original jobs: 59 | Filtered jobs: 34
# Processing file: job_listings_20240831_archive.json
# File: job_listings_20240831_archive.json | Original jobs: 3 | Filtered jobs: 3
# Processing file: job_listings_20240902_archive.json
# File: job_listings_20240902_archive.json | Original jobs: 61 | Filtered jobs: 35
# Processing file: job_listings_20240903_archive.json
# File: job_listings_20240903_archive.json | Original jobs: 78 | Filtered jobs: 50
# Processing file: job_listings_20240904_archive.json
# File: job_listings_20240904_archive.json | Original jobs: 53 | Filtered jobs: 34
# Processing file: job_listings_20240905_archive.json
# File: job_listings_20240905_archive.json | Original jobs: 59 | Filtered jobs: 34
# Processing file: job_listings_20240906_archive.json
# File: job_listings_20240906_archive.json | Original jobs: 57 | Filtered jobs: 36
# Processing file: job_listings_20240907_archive.json
# File: job_listings_20240907_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20240909_archive.json
# File: job_listings_20240909_archive.json | Original jobs: 65 | Filtered jobs: 42
# Processing file: job_listings_20240910_archive.json
# File: job_listings_20240910_archive.json | Original jobs: 68 | Filtered jobs: 41
# Processing file: job_listings_20240911_archive.json
# File: job_listings_20240911_archive.json | Original jobs: 72 | Filtered jobs: 44
# Processing file: job_listings_20240912_archive.json
# File: job_listings_20240912_archive.json | Original jobs: 73 | Filtered jobs: 42
# Processing file: job_listings_20240913_archive.json
# File: job_listings_20240913_archive.json | Original jobs: 46 | Filtered jobs: 25
# Processing file: job_listings_20240914_archive.json
# File: job_listings_20240914_archive.json | Original jobs: 6 | Filtered jobs: 4
# Processing file: job_listings_20240915_archive.json
# File: job_listings_20240915_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20240916_archive.json
# File: job_listings_20240916_archive.json | Original jobs: 71 | Filtered jobs: 44
# Processing file: job_listings_20240917_archive.json
# File: job_listings_20240917_archive.json | Original jobs: 69 | Filtered jobs: 46
# Processing file: job_listings_20240918_archive.json
# File: job_listings_20240918_archive.json | Original jobs: 58 | Filtered jobs: 36
# Processing file: job_listings_20240919_archive.json
# File: job_listings_20240919_archive.json | Original jobs: 51 | Filtered jobs: 28
# Processing file: job_listings_20240920_archive.json
# File: job_listings_20240920_archive.json | Original jobs: 64 | Filtered jobs: 35
# Processing file: job_listings_20240921_archive.json
# File: job_listings_20240921_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20240922_archive.json
# File: job_listings_20240922_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20240923_archive.json
# File: job_listings_20240923_archive.json | Original jobs: 58 | Filtered jobs: 31
# Processing file: job_listings_20240924_archive.json
# File: job_listings_20240924_archive.json | Original jobs: 50 | Filtered jobs: 36
# Processing file: job_listings_20240925_archive.json
# File: job_listings_20240925_archive.json | Original jobs: 52 | Filtered jobs: 34
# Processing file: job_listings_20240926_archive.json
# File: job_listings_20240926_archive.json | Original jobs: 37 | Filtered jobs: 25
# Processing file: job_listings_20240927_archive.json
# File: job_listings_20240927_archive.json | Original jobs: 42 | Filtered jobs: 21
# Processing file: job_listings_20240928_archive.json
# File: job_listings_20240928_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20240929_archive.json
# File: job_listings_20240929_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20240930_archive.json
# File: job_listings_20240930_archive.json | Original jobs: 48 | Filtered jobs: 30
# Processing file: job_listings_20241001_archive.json
# File: job_listings_20241001_archive.json | Original jobs: 75 | Filtered jobs: 39
# Processing file: job_listings_20241002_archive.json
# File: job_listings_20241002_archive.json | Original jobs: 62 | Filtered jobs: 35
# Processing file: job_listings_20241003_archive.json
# File: job_listings_20241003_archive.json | Original jobs: 63 | Filtered jobs: 39
# Processing file: job_listings_20241004_archive.json
# File: job_listings_20241004_archive.json | Original jobs: 74 | Filtered jobs: 44
# Processing file: job_listings_20241005_archive.json
# File: job_listings_20241005_archive.json | Original jobs: 3 | Filtered jobs: 3
# Processing file: job_listings_20241006_archive.json
# File: job_listings_20241006_archive.json | Original jobs: 1 | Filtered jobs: 1
# Processing file: job_listings_20241007_archive.json
# File: job_listings_20241007_archive.json | Original jobs: 55 | Filtered jobs: 39
# Processing file: job_listings_20241008_archive.json
# File: job_listings_20241008_archive.json | Original jobs: 65 | Filtered jobs: 42
# Processing file: job_listings_20241009_archive.json
# File: job_listings_20241009_archive.json | Original jobs: 53 | Filtered jobs: 34
# Processing file: job_listings_20241010_archive.json
# File: job_listings_20241010_archive.json | Original jobs: 58 | Filtered jobs: 34
# Processing file: job_listings_20241011_archive.json
# File: job_listings_20241011_archive.json | Original jobs: 63 | Filtered jobs: 45
# Processing file: job_listings_20241012_archive.json
# File: job_listings_20241012_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20241013_archive.json
# File: job_listings_20241013_archive.json | Original jobs: 4 | Filtered jobs: 2
# Processing file: job_listings_20241014_archive.json
# File: job_listings_20241014_archive.json | Original jobs: 49 | Filtered jobs: 33
# Processing file: job_listings_20241015_archive.json
# File: job_listings_20241015_archive.json | Original jobs: 45 | Filtered jobs: 22
# Processing file: job_listings_20241016_archive.json
# File: job_listings_20241016_archive.json | Original jobs: 47 | Filtered jobs: 33
# Processing file: job_listings_20241017_archive.json
# File: job_listings_20241017_archive.json | Original jobs: 49 | Filtered jobs: 21
# Processing file: job_listings_20241018_archive.json
# File: job_listings_20241018_archive.json | Original jobs: 43 | Filtered jobs: 31
# Processing file: job_listings_20241019_archive.json
# File: job_listings_20241019_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20241020_archive.json
# File: job_listings_20241020_archive.json | Original jobs: 2 | Filtered jobs: 1
# Processing file: job_listings_20241021_archive.json
# File: job_listings_20241021_archive.json | Original jobs: 42 | Filtered jobs: 30
# Processing file: job_listings_20241022_archive.json
# File: job_listings_20241022_archive.json | Original jobs: 33 | Filtered jobs: 20
# Processing file: job_listings_20241023_archive.json
# File: job_listings_20241023_archive.json | Original jobs: 46 | Filtered jobs: 31
# Processing file: job_listings_20241024_archive.json
# File: job_listings_20241024_archive.json | Original jobs: 43 | Filtered jobs: 24
# Processing file: job_listings_20241025_archive.json
# File: job_listings_20241025_archive.json | Original jobs: 52 | Filtered jobs: 29
# Processing file: job_listings_20241026_archive.json
# File: job_listings_20241026_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20241027_archive.json
# File: job_listings_20241027_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20241028_archive.json
# File: job_listings_20241028_archive.json | Original jobs: 51 | Filtered jobs: 33
# Processing file: job_listings_20241029_archive.json
# File: job_listings_20241029_archive.json | Original jobs: 30 | Filtered jobs: 18
# Processing file: job_listings_20241030_archive.json
# File: job_listings_20241030_archive.json | Original jobs: 35 | Filtered jobs: 19
# Processing file: job_listings_20241031_archive.json
# File: job_listings_20241031_archive.json | Original jobs: 34 | Filtered jobs: 20
# Processing file: job_listings_20241101_archive.json
# File: job_listings_20241101_archive.json | Original jobs: 38 | Filtered jobs: 22
# Processing file: job_listings_20241102_archive.json
# File: job_listings_20241102_archive.json | Original jobs: 1 | Filtered jobs: 0
# Processing file: job_listings_20241104_archive.json
# File: job_listings_20241104_archive.json | Original jobs: 20 | Filtered jobs: 15
# Processing file: job_listings_20241105_archive.json
# File: job_listings_20241105_archive.json | Original jobs: 33 | Filtered jobs: 25
# Processing file: job_listings_20241106_archive.json
# File: job_listings_20241106_archive.json | Original jobs: 23 | Filtered jobs: 14
# Processing file: job_listings_20241107_archive.json
# File: job_listings_20241107_archive.json | Original jobs: 29 | Filtered jobs: 15
# Processing file: job_listings_20241108_archive.json
# File: job_listings_20241108_archive.json | Original jobs: 19 | Filtered jobs: 16
# Processing file: job_listings_20241109_archive.json
# File: job_listings_20241109_archive.json | Original jobs: 3 | Filtered jobs: 2
# Processing file: job_listings_20241110_archive.json
# File: job_listings_20241110_archive.json | Original jobs: 2 | Filtered jobs: 2
# Processing file: job_listings_20241111_archive.json
# File: job_listings_20241111_archive.json | Original jobs: 20 | Filtered jobs: 11
# Processing file: job_listings_20241112_archive.json
# File: job_listings_20241112_archive.json | Original jobs: 12 | Filtered jobs: 6
# Processing file: job_listings_20241113_archive.json
# File: job_listings_20241113_archive.json | Original jobs: 13 | Filtered jobs: 7
# Processing file: job_listings_20241114_archive.json
# File: job_listings_20241114_archive.json | Original jobs: 9 | Filtered jobs: 5
# Processing file: job_listings_20241115_archive.json
# File: job_listings_20241115_archive.json | Original jobs: 8 | Filtered jobs: 7
# Processing file: job_listings_20241118_archive.json
# File: job_listings_20241118_archive.json | Original jobs: 6 | Filtered jobs: 5
# Processing file: job_listings_20241119_archive.json
# File: job_listings_20241119_archive.json | Original jobs: 5 | Filtered jobs: 3
# Processing file: job_listings_20241120_archive.json
# File: job_listings_20241120_archive.json | Original jobs: 4 | Filtered jobs: 3
# Processing file: job_listings_20241121_archive.json
# File: job_listings_20241121_archive.json | Original jobs: 1 | Filtered jobs: 1
# All files have been processed. Filtered files are saved in the 'archive_filtered' directory.
