# %%
import os
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# Function to load progress from progress.json
def load_progress(progress_file):
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as file:
            return json.load(file)
    return {"processed_files": []}

# Function to save progress to progress.json
def save_progress(progress_file, processed_files):
    with open(progress_file, 'w') as file:
        json.dump({"processed_files": processed_files}, file)

# Function to convert Jobindex URL to archive URL
def generate_archive_url(job_url):
    try:
        # Validate the input URL
        if not isinstance(job_url, str) or not job_url.startswith("https://www.jobindex.dk/vis-job/"):
            return {"Job Link": "Invalid Job URL", "Content": None}
        
        # Extract the job ID from the URL
        job_id = job_url.split('/')[-1].strip()  # Get the part after the last "/" and remove extra spaces
        
        # Check if job_id is non-empty
        if not job_id:
            return {"Job Link": "Invalid Job ID", "Content": None}
        
        # Construct the archive URL
        archive_url = f"https://www.jobindexarkiv.dk/cgi/showarchive.cgi?tid={job_id}"
        return {"Job Link": archive_url}
    except Exception as e:
        return {"Job Link": f"Error: {str(e)}", "Content": None}



# Function to process a single file
def process_file(filename, input_folder, output_folder, progress_file, processed_files):
    if not filename.endswith('.json'):
        return f"Skipping non-JSON file: {filename}"

    output_json_path = os.path.join(output_folder, filename.replace('.json', '_archive.json'))

    # Check if the output file already exists
    if os.path.exists(output_json_path):
        return f"Skipping file (already processed): {filename}"

    input_file_path = os.path.join(input_folder, filename)
    print(f"Processing file: {filename}")

    try:
        # Load the JSON file into a DataFrame
        df = pd.read_json(input_file_path)

        # Apply the generate_archive_url function to generate archive URLs
        results = df['URL'].apply(generate_archive_url)

        # Extract 'Job Link' into a separate column
        df['Job Link'] = results.apply(lambda x: x['Job Link'])

        # Save the updated DataFrame as JSON
        df.to_json(output_json_path, orient='records', indent=4)

        # Update progress after processing the file
        processed_files.append(filename)
        save_progress(progress_file, processed_files)

        return f"Processed and saved: {filename}"
    except Exception as e:
        return f"Error processing {filename}: {str(e)}"

# Directories
input_folder = 'Merged_Job_Listings'
output_folder = 'Merged_Job_Listings_with_ArchiveLink'
progress_file = '[STEP2]generate_archive_url_html_progress_log.json'

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load progress
progress = load_progress(progress_file)
processed_files = progress.get("processed_files", [])

# List all JSON files in the input folder, sorted for consistent ordering
files_to_process = sorted([f for f in os.listdir(input_folder) if f.endswith('.json')])

# Exclude already processed files
files_to_process = [f for f in files_to_process if f not in processed_files]

# Use ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor(max_workers=10) as executor:
    futures = {
        executor.submit(process_file, f, input_folder, output_folder, progress_file, processed_files): f
        for f in files_to_process
    }

    for future in futures:
        try:
            print(future.result())
        except Exception as e:
            print(f"Error with file {futures[future]}: {str(e)}")
# Out:
# Processing file: job_listings_20160101.json
# Processing file: job_listings_20160102.json
# Processing file: job_listings_20160103.json
# Processing file: job_listings_20160104.json
# Processing file: job_listings_20160105.json
# Processing file: job_listings_20160106.json
# Processing file: job_listings_20160107.json
# Processing file: job_listings_20160108.json
# Processing file: job_listings_20160109.json
# Processing file: job_listings_20160110.json
# Processing file: job_listings_20160111.json
# Processed and saved: job_listings_20160101.json
# Processing file: job_listings_20160113.json
# Processing file: job_listings_20160112.json
# Processing file: job_listings_20160114.json
# Processing file: job_listings_20160115.json
# Processed and saved: job_listings_20160102.json
# Processed and saved: job_listings_20160103.json
# Processed and saved: job_listings_20160104.json
# Processed and saved: job_listings_20160105.json
# Processed and saved: job_listings_20160106.json
# Processing file: job_listings_20160118.json
# Processing file: job_listings_20160116.json
# Processed and saved: job_listings_20160107.json
# Processing file: job_listings_20160117.json
# Processing file: job_listings_20160119.json
# Processed and saved: job_listings_20160108.json
# Processing file: job_listings_20160120.json
# Processed and saved: job_listings_20160109.json
# Processed and saved: job_listings_20160110.json
# Processing file: job_listings_20160121.json
# Processing file: job_listings_20160122.json
# Processing file: job_listings_20160123.json
# Processed and saved: job_listings_20160111.json
# Processed and saved: job_listings_20160112.json
# Processed and saved: job_listings_20160113.json
# Processed and saved: job_listings_20160114.json
# Processing file: job_listings_20160124.json
# Processing file: job_listings_20160125.json
# Processing file: job_listings_20160126.json
# Processing file: job_listings_20160127.json
# Processed and saved: job_listings_20160115.json
# Processed and saved: job_listings_20160116.json
# Processed and saved: job_listings_20160117.json
# Processed and saved: job_listings_20160118.json
# Processing file: job_listings_20160128.json
# Processing file: job_listings_20160129.json
# Processed and saved: job_listings_20160119.json
# Processing file: job_listings_20160130.json
# Processed and saved: job_listings_20160120.json
# Processing file: job_listings_20160201.json
# Processed and saved: job_listings_20160121.json
# Processed and saved: job_listings_20160122.json
# Processing file: job_listings_20160131.json
# Processing file: job_listings_20160202.json
# Processing file: job_listings_20160203.json
# Processed and saved: job_listings_20160123.json
# Processing file: job_listings_20160204.json
# Processed and saved: job_listings_20160124.json
# Processed and saved: job_listings_20160125.json
# Processing file: job_listings_20160205.json
# Processing file: job_listings_20160207.json
# Processed and saved: job_listings_20160126.json
# Processed and saved: job_listings_20160127.json
# Processing file: job_listings_20160206.json
# Processed and saved: job_listings_20160128.json
# Processed and saved: job_listings_20160129.json
# Processing file: job_listings_20160208.json
# Processing file: job_listings_20160209.json
# Processing file: job_listings_20160210.json
# Processed and saved: job_listings_20160130.json
# Processing file: job_listings_20160211.json
# Processing file: job_listings_20160212.json
# Processing file: job_listings_20160213.json
# Processing file: job_listings_20160215.json
# Processing file: job_listings_20160214.json
# Processed and saved: job_listings_20160131.json
# Processed and saved: job_listings_20160201.json
# Processed and saved: job_listings_20160202.json
# Processed and saved: job_listings_20160203.json
# Processed and saved: job_listings_20160204.json
# Processed and saved: job_listings_20160205.json
# Processing file: job_listings_20160216.json
# Processed and saved: job_listings_20160206.json
# Processing file: job_listings_20160218.json
# Processing file: job_listings_20160217.json
# Processed and saved: job_listings_20160207.json
# Processed and saved: job_listings_20160208.json
# Processing file: job_listings_20160219.json
# Processed and saved: job_listings_20160209.json
# Processed and saved: job_listings_20160210.json
# Processed and saved: job_listings_20160211.json
# Processing file: job_listings_20160220.json
# Processed and saved: job_listings_20160212.json
# Processed and saved: job_listings_20160213.json
# Processing file: job_listings_20160223.json
# Processing file: job_listings_20160222.json
# Processing file: job_listings_20160221.json
# Processing file: job_listings_20160224.json
# Processing file: job_listings_20160225.json
# Processed and saved: job_listings_20160214.json
# Processed and saved: job_listings_20160215.json
# Processed and saved: job_listings_20160216.json
# Processing file: job_listings_20160226.json
# Processing file: job_listings_20160227.json
# Processed and saved: job_listings_20160217.jsonProcessing file: job_listings_20160229.json
# Processing file: job_listings_20160301.json
# Processing file: job_listings_20160228.json
#
# Processed and saved: job_listings_20160218.json
# Processed and saved: job_listings_20160219.json
# Processing file: job_listings_20160302.json
# Processing file: job_listings_20160304.json
# Processing file: job_listings_20160305.json
# Processing file: job_listings_20160303.json
# Processed and saved: job_listings_20160220.json
# Processed and saved: job_listings_20160221.json
# Processed and saved: job_listings_20160222.json
# Processed and saved: job_listings_20160223.json
# Processed and saved: job_listings_20160224.json
# Processing file: job_listings_20160306.json
# Processing file: job_listings_20160307.json
# Processing file: job_listings_20160308.json
# Processed and saved: job_listings_20160225.json
# Processed and saved: job_listings_20160226.json
# Processed and saved: job_listings_20160227.json
# Processing file: job_listings_20160309.json
# Processing file: job_listings_20160311.json
# Processing file: job_listings_20160310.json
# Processing file: job_listings_20160312.json
# Processed and saved: job_listings_20160228.json
# Processed and saved: job_listings_20160229.json
# Processed and saved: job_listings_20160301.json
# Processed and saved: job_listings_20160302.json
# Processed and saved: job_listings_20160303.json
# Processing file: job_listings_20160313.json
# Processing file: job_listings_20160314.json
# Processing file: job_listings_20160315.json
# Processing file: job_listings_20160316.json
# Processing file: job_listings_20160317.json
# Processed and saved: job_listings_20160304.json
# Processed and saved: job_listings_20160305.json
# Processed and saved: job_listings_20160306.json
# Processed and saved: job_listings_20160307.json
# Processing file: job_listings_20160319.json
# Processed and saved: job_listings_20160308.json
# Processed and saved: job_listings_20160309.json
# Processing file: job_listings_20160318.json
# Processed and saved: job_listings_20160310.json
# Processing file: job_listings_20160320.json
# Processing file: job_listings_20160322.json
# Processing file: job_listings_20160321.json
# Processed and saved: job_listings_20160311.json
# Processed and saved: job_listings_20160312.json
# Processing file: job_listings_20160323.json
# Processing file: job_listings_20160324.json
# Processing file: job_listings_20160325.json
# Processed and saved: job_listings_20160313.json
# Processed and saved: job_listings_20160314.json
# Processed and saved: job_listings_20160315.json
# Processed and saved: job_listings_20160316.json
# Processing file: job_listings_20160326.json
# Processing file: job_listings_20160328.json
# Processing file: job_listings_20160327.json
# Processing file: job_listings_20160329.json
# Processing file: job_listings_20160330.json
# Processed and saved: job_listings_20160317.json
# Processed and saved: job_listings_20160318.json
# Processed and saved: job_listings_20160319.json
# Processed and saved: job_listings_20160320.json
# Processing file: job_listings_20160331.json
# Processed and saved: job_listings_20160321.json
# Processed and saved: job_listings_20160322.json
# Processing file: job_listings_20160402.json
# Processing file: job_listings_20160401.json
# Processed and saved: job_listings_20160323.json
# Processing file: job_listings_20160403.json
# Processing file: job_listings_20160404.json
# Processed and saved: job_listings_20160324.json
# Processed and saved: job_listings_20160325.json
# Processing file: job_listings_20160406.json
# Processed and saved: job_listings_20160326.json
# Processing file: job_listings_20160405.json
# Processing file: job_listings_20160407.json
# Processing file: job_listings_20160408.json
# Processing file: job_listings_20160409.json
# Processed and saved: job_listings_20160327.json
# Processed and saved: job_listings_20160328.json
# Processed and saved: job_listings_20160329.json
# Processed and saved: job_listings_20160330.json
# Processing file: job_listings_20160410.json
# Processed and saved: job_listings_20160331.json
# Processing file: job_listings_20160412.json
# Processing file: job_listings_20160411.json
# Processed and saved: job_listings_20160401.json
# Processed and saved: job_listings_20160402.json
# Processing file: job_listings_20160414.json
# Processing file: job_listings_20160413.json
# Processing file: job_listings_20160415.json
# Processed and saved: job_listings_20160403.json
# Processed and saved: job_listings_20160404.json
# Processed and saved: job_listings_20160405.json
# Processing file: job_listings_20160416.json
# Processing file: job_listings_20160418.json
# Processing file: job_listings_20160419.json
# Processed and saved: job_listings_20160406.json
# Processed and saved: job_listings_20160407.json
# Processed and saved: job_listings_20160408.json
# Processed and saved: job_listings_20160409.json
# Processing file: job_listings_20160420.json
# Processing file: job_listings_20160421.json
# Processed and saved: job_listings_20160410.jsonProcessing file: job_listings_20160422.json
#
# Processed and saved: job_listings_20160411.json
# Processing file: job_listings_20160423.json
# Processing file: job_listings_20160424.json
# Processing file: job_listings_20160425.json
# Processed and saved: job_listings_20160412.json
# Processed and saved: job_listings_20160413.json
# Processed and saved: job_listings_20160414.json
# Processed and saved: job_listings_20160415.json
# Processed and saved: job_listings_20160416.json
# Processing file: job_listings_20160426.json
# Processing file: job_listings_20160427.json
# Processing file: job_listings_20160428.json
# Processing file: job_listings_20160429.json
# Processed and saved: job_listings_20160418.json
# Processed and saved: job_listings_20160419.json
# Processed and saved: job_listings_20160420.json
# Processing file: job_listings_20160430.json
# Processed and saved: job_listings_20160421.json
# Processing file: job_listings_20160501.json
# Processing file: job_listings_20160502.json
# Processed and saved: job_listings_20160422.json
# Processed and saved: job_listings_20160423.json
# Processed and saved: job_listings_20160424.json
# Processed and saved: job_listings_20160425.json
# Processing file: job_listings_20160505.json
# Processing file: job_listings_20160506.json
# Processing file: job_listings_20160507.json
# Processing file: job_listings_20160503.json
# Processed and saved: job_listings_20160426.json
# Processing file: job_listings_20160504.json
# Processing file: job_listings_20160508.json
# Processed and saved: job_listings_20160427.json
# Processed and saved: job_listings_20160428.json
# Processed and saved: job_listings_20160429.json
# Processing file: job_listings_20160509.json
# Processed and saved: job_listings_20160430.json
# Processing file: job_listings_20160510.json
# Processed and saved: job_listings_20160501.json
# Processing file: job_listings_20160511.json
# Processed and saved: job_listings_20160502.json
# Processing file: job_listings_20160512.json
# Processing file: job_listings_20160513.json
# Processed and saved: job_listings_20160503.json
# Processing file: job_listings_20160515.json
# Processing file: job_listings_20160514.json
# Processing file: job_listings_20160516.json
# Processing file: job_listings_20160517.json
# Processed and saved: job_listings_20160504.json
# Processed and saved: job_listings_20160505.json
# Processed and saved: job_listings_20160506.json
# Processed and saved: job_listings_20160507.json
# Processed and saved: job_listings_20160508.json
# Processed and saved: job_listings_20160509.json
# Processing file: job_listings_20160519.json
# Processing file: job_listings_20160518.json
# Processing file: job_listings_20160520.json
# Processing file: job_listings_20160521.json
# Processing file: job_listings_20160522.json
# Processed and saved: job_listings_20160510.json
# Processed and saved: job_listings_20160511.json
# Processed and saved: job_listings_20160512.json
# Processing file: job_listings_20160524.json
# Processing file: job_listings_20160523.json
# Processing file: job_listings_20160525.json
# Processing file: job_listings_20160526.json
# Processed and saved: job_listings_20160513.json
# Processing file: job_listings_20160528.json
# Processing file: job_listings_20160527.json
# Processed and saved: job_listings_20160514.json
# Processed and saved: job_listings_20160515.json
# Processed and saved: job_listings_20160516.json
# Processed and saved: job_listings_20160517.json
# Processed and saved: job_listings_20160518.json
# Processed and saved: job_listings_20160519.json
# Processing file: job_listings_20160529.json
# Processed and saved: job_listings_20160520.json
# Processing file: job_listings_20160530.json
# Processed and saved: job_listings_20160521.json
# Processed and saved: job_listings_20160522.json
# Processing file: job_listings_20160531.json
# Processing file: job_listings_20160601.json
# Processing file: job_listings_20160602.json
# Processing file: job_listings_20160603.json
# Processing file: job_listings_20160604.json
# Processing file: job_listings_20160605.json
# Processing file: job_listings_20160606.json
# Processing file: job_listings_20160607.json
# Processing file: job_listings_20160608.json
# Processed and saved: job_listings_20160523.json
# Processed and saved: job_listings_20160524.json
# Processed and saved: job_listings_20160525.json
# Processed and saved: job_listings_20160526.json
# Processed and saved: job_listings_20160527.json
# Processed and saved: job_listings_20160528.json
# Processed and saved: job_listings_20160529.json
# Processed and saved: job_listings_20160530.json
# Processing file: job_listings_20160609.json
# Processing file: job_listings_20160610.json
# Processed and saved: job_listings_20160531.json
# Processing file: job_listings_20160611.json
# Processed and saved: job_listings_20160601.json
# Processing file: job_listings_20160614.json
# Processing file: job_listings_20160613.json
# Processed and saved: job_listings_20160602.json
# Processed and saved: job_listings_20160603.json
# Processed and saved: job_listings_20160604.json
# Processing file: job_listings_20160615.json
# Processing file: job_listings_20160616.json
# Processed and saved: job_listings_20160605.json
# Processed and saved: job_listings_20160606.json
# Processing file: job_listings_20160617.json
# Processing file: job_listings_20160618.json
# Processing file: job_listings_20160620.json
# Processed and saved: job_listings_20160607.json
# Processed and saved: job_listings_20160608.json
# Processed and saved: job_listings_20160609.json
# Processing file: job_listings_20160621.json
# Processing file: job_listings_20160622.json
# Processing file: job_listings_20160623.json
# Processed and saved: job_listings_20160610.json
# Processed and saved: job_listings_20160611.json
# Processed and saved: job_listings_20160613.json
# Processing file: job_listings_20160624.json
# Processed and saved: job_listings_20160614.json
# Processing file: job_listings_20160625.json
# Processing file: job_listings_20160627.json
# Processing file: job_listings_20160628.json
# Processing file: job_listings_20160629.json
# Processing file: job_listings_20160630.json
# Processing file: job_listings_20160701.json
# Processed and saved: job_listings_20160615.json
# Processed and saved: job_listings_20160616.json
# Processed and saved: job_listings_20160617.json
# Processed and saved: job_listings_20160618.json
# Processed and saved: job_listings_20160620.json
# Processed and saved: job_listings_20160621.json
# Processing file: job_listings_20160702.json
# Processing file: job_listings_20160703.json
# Processing file: job_listings_20160705.json
# Processing file: job_listings_20160704.json
# Processing file: job_listings_20160707.json
# Processed and saved: job_listings_20160622.json
# Processed and saved: job_listings_20160623.json
# Processed and saved: job_listings_20160624.json
# Processed and saved: job_listings_20160625.json
# Processed and saved: job_listings_20160627.json
# Processing file: job_listings_20160706.json
# Processed and saved: job_listings_20160628.json
# Processing file: job_listings_20160708.json
# Processing file: job_listings_20160709.json
# Processing file: job_listings_20160710.json
# Processing file: job_listings_20160711.json
# Processed and saved: job_listings_20160629.json
# Processed and saved: job_listings_20160630.json
# Processed and saved: job_listings_20160701.json
# Processing file: job_listings_20160712.json
# Processed and saved: job_listings_20160702.json
# Processed and saved: job_listings_20160703.json
# Processing file: job_listings_20160713.json
# Processing file: job_listings_20160714.json
# Processing file: job_listings_20160718.json
# Processing file: job_listings_20160715.json
# Processing file: job_listings_20160716.json
# Processing file: job_listings_20160717.json
# Processed and saved: job_listings_20160704.json
# Processed and saved: job_listings_20160705.json
# Processed and saved: job_listings_20160706.json
# Processed and saved: job_listings_20160707.json
# Processed and saved: job_listings_20160708.json
# Processing file: job_listings_20160719.json
# Processing file: job_listings_20160721.json
# Processed and saved: job_listings_20160709.json
# Processed and saved: job_listings_20160710.json
# Processed and saved: job_listings_20160711.json
# Processing file: job_listings_20160720.json
# Processing file: job_listings_20160722.json
# Processed and saved: job_listings_20160712.json
# Processing file: job_listings_20160723.json
# Processing file: job_listings_20160724.json
# Processing file: job_listings_20160725.json
# Processing file: job_listings_20160726.json
# Processed and saved: job_listings_20160713.json
# Processing file: job_listings_20160727.json
# Processing file: job_listings_20160728.json
# Processing file: job_listings_20160729.json
# Processed and saved: job_listings_20160714.json
# Processed and saved: job_listings_20160715.json
# Processing file: job_listings_20160730.json
# Processing file: job_listings_20160731.json
# Processed and saved: job_listings_20160716.json
# Processed and saved: job_listings_20160717.json
# Processed and saved: job_listings_20160718.json
# Processed and saved: job_listings_20160719.json
# Processed and saved: job_listings_20160720.json
# Processed and saved: job_listings_20160721.json
# Processing file: job_listings_20160801.json
# Processed and saved: job_listings_20160722.json
# Processed and saved: job_listings_20160723.json
# Processing file: job_listings_20160802.json
# Processed and saved: job_listings_20160724.json
# Processing file: job_listings_20160803.json
# Processed and saved: job_listings_20160725.json
# Processing file: job_listings_20160805.json
# Processing file: job_listings_20160804.json
# Processed and saved: job_listings_20160726.json
# Processing file: job_listings_20160807.json
# Processing file: job_listings_20160806.json
# Processed and saved: job_listings_20160727.json
# Processing file: job_listings_20160808.json
# Processing file: job_listings_20160809.json
# Processed and saved: job_listings_20160728.json
# Processed and saved: job_listings_20160729.json
# Processed and saved: job_listings_20160730.json
# Processed and saved: job_listings_20160731.json
# Processing file: job_listings_20160810.json
# Processed and saved: job_listings_20160801.json
# Processed and saved: job_listings_20160802.json
# Processing file: job_listings_20160811.json
# Processing file: job_listings_20160812.json
# Processed and saved: job_listings_20160803.json
# Processing file: job_listings_20160814.json
# Processing file: job_listings_20160813.json
# Processing file: job_listings_20160815.json
# Processing file: job_listings_20160816.json
# Processing file: job_listings_20160817.json
# Processing file: job_listings_20160818.json
# Processed and saved: job_listings_20160804.json
# Processed and saved: job_listings_20160805.json
# Processed and saved: job_listings_20160806.json
# Processed and saved: job_listings_20160807.json
# Processing file: job_listings_20160819.json
# Processing file: job_listings_20160820.json
# Processing file: job_listings_20160821.json
# Processing file: job_listings_20160822.json
# Processed and saved: job_listings_20160808.json
# Processed and saved: job_listings_20160809.json
# Processed and saved: job_listings_20160810.json
# Processed and saved: job_listings_20160811.json
# Processed and saved: job_listings_20160812.json
# Processed and saved: job_listings_20160813.json
# Processing file: job_listings_20160823.json
# Processed and saved: job_listings_20160814.json
# Processing file: job_listings_20160824.json
# Processed and saved: job_listings_20160815.json
# Processed and saved: job_listings_20160816.json
# Processing file: job_listings_20160825.json
# Processing file: job_listings_20160826.json
# Processed and saved: job_listings_20160817.json
# Processing file: job_listings_20160829.json
# Processing file: job_listings_20160830.json
# Processing file: job_listings_20160901.json
# Processing file: job_listings_20160831.json
# Processed and saved: job_listings_20160818.json
# Processing file: job_listings_20160902.json
# Processed and saved: job_listings_20160819.jsonProcessing file: job_listings_20160905.json
#
# Processed and saved: job_listings_20160820.json
# Processed and saved: job_listings_20160821.json
# Processed and saved: job_listings_20160822.json
# Processing file: job_listings_20160906.json
# Processed and saved: job_listings_20160823.json
# Processing file: job_listings_20160907.json
# Processing file: job_listings_20160908.json
# Processing file: job_listings_20160909.json
# Processing file: job_listings_20160910.json
# Processing file: job_listings_20160911.json
# Processed and saved: job_listings_20160824.json
# Processed and saved: job_listings_20160825.json
# Processed and saved: job_listings_20160826.json
# Processed and saved: job_listings_20160829.json
# Processing file: job_listings_20160912.json
# Processed and saved: job_listings_20160830.json
# Processed and saved: job_listings_20160831.json
# Processed and saved: job_listings_20160901.json
# Processing file: job_listings_20160913.json
# Processing file: job_listings_20160914.json
# Processed and saved: job_listings_20160902.json
# Processing file: job_listings_20160915.json
# Processed and saved: job_listings_20160905.json
# Processing file: job_listings_20160916.json
# Processing file: job_listings_20160917.json
# Processed and saved: job_listings_20160906.json
# Processed and saved: job_listings_20160907.json
# Processed and saved: job_listings_20160908.json
# Processing file: job_listings_20160918.json
# Processing file: job_listings_20160919.json
# Processed and saved: job_listings_20160909.json
# Processed and saved: job_listings_20160910.json
# Processing file: job_listings_20160920.json
# Processing file: job_listings_20160921.json
# Processed and saved: job_listings_20160911.json
# Processed and saved: job_listings_20160912.json
# Processing file: job_listings_20160922.json
# Processing file: job_listings_20160923.json
# Processing file: job_listings_20160924.json
# Processed and saved: job_listings_20160913.json
# Processed and saved: job_listings_20160914.json
# Processing file: job_listings_20160925.json
# Processed and saved: job_listings_20160915.json
# Processed and saved: job_listings_20160916.json
# Processed and saved: job_listings_20160917.json
# Processing file: job_listings_20160927.json
# Processing file: job_listings_20160926.json
# Processing file: job_listings_20160928.json
# Processed and saved: job_listings_20160918.json
# Processed and saved: job_listings_20160919.json
# Processing file: job_listings_20160929.json
# Processed and saved: job_listings_20160920.json
# Processing file: job_listings_20160930.json
# Processing file: job_listings_20161001.json
# Processed and saved: job_listings_20160921.json
# Processed and saved: job_listings_20160922.json
# Processing file: job_listings_20161002.json
# Processing file: job_listings_20161003.json
# Processed and saved: job_listings_20160923.json
# Processing file: job_listings_20161004.json
# Processing file: job_listings_20161005.json
# Processing file: job_listings_20161007.json
# Processing file: job_listings_20161006.json
# Processed and saved: job_listings_20160924.json
# Processed and saved: job_listings_20160925.json
# Processed and saved: job_listings_20160926.json
# Processed and saved: job_listings_20160927.json
# Processing file: job_listings_20161008.json
# Processing file: job_listings_20161009.json
# Processed and saved: job_listings_20160928.json
# Processing file: job_listings_20161011.json
# Processing file: job_listings_20161010.json
# Processed and saved: job_listings_20160929.json
# Processed and saved: job_listings_20160930.json
# Processed and saved: job_listings_20161001.json
# Processed and saved: job_listings_20161002.json
# Processed and saved: job_listings_20161003.json
# Processing file: job_listings_20161012.json
# Processing file: job_listings_20161013.json
# Processed and saved: job_listings_20161004.json
# Processing file: job_listings_20161014.json
# Processing file: job_listings_20161015.json
# Processing file: job_listings_20161017.json
# Processing file: job_listings_20161019.json
# Processing file: job_listings_20161016.json
# Processed and saved: job_listings_20161005.json
# Processed and saved: job_listings_20161006.json
# Processed and saved: job_listings_20161007.json
# Processed and saved: job_listings_20161008.json
# Processed and saved: job_listings_20161009.json
# Processing file: job_listings_20161021.json
# Processing file: job_listings_20161018.json
# Processing file: job_listings_20161020.json
# Processing file: job_listings_20161022.json
# Processed and saved: job_listings_20161010.json
# Processed and saved: job_listings_20161011.json
# Processed and saved: job_listings_20161012.json
# Processed and saved: job_listings_20161013.json
# Processing file: job_listings_20161023.json
# Processing file: job_listings_20161024.json
# Processed and saved: job_listings_20161014.json
# Processed and saved: job_listings_20161015.json
# Processing file: job_listings_20161025.json
# Processing file: job_listings_20161026.json
# Processing file: job_listings_20161027.json
# Processing file: job_listings_20161028.json
# Processed and saved: job_listings_20161016.json
# Processed and saved: job_listings_20161017.json
# Processed and saved: job_listings_20161018.json
# Processing file: job_listings_20161029.json
# Processing file: job_listings_20161031.json
# Processing file: job_listings_20161102.json
# Processed and saved: job_listings_20161019.json
# Processed and saved: job_listings_20161020.json
# Processed and saved: job_listings_20161021.json
# Processed and saved: job_listings_20161022.json
# Processing file: job_listings_20161101.json
# Processing file: job_listings_20161103.json
# Processing file: job_listings_20161104.json
# Processed and saved: job_listings_20161023.json
# Processed and saved: job_listings_20161024.json
# Processing file: job_listings_20161106.json
# Processing file: job_listings_20161107.json
# Processing file: job_listings_20161108.json
# Processed and saved: job_listings_20161025.json
# Processed and saved: job_listings_20161026.json
# Processed and saved: job_listings_20161027.json
# Processing file: job_listings_20161110.jsonProcessed and saved: job_listings_20161028.json
# Processed and saved: job_listings_20161029.json
# Processing file: job_listings_20161109.json
#
# Processing file: job_listings_20161111.json
# Processed and saved: job_listings_20161031.json
# Processing file: job_listings_20161112.json
# Processing file: job_listings_20161114.json
# Processed and saved: job_listings_20161101.json
# Processed and saved: job_listings_20161102.json
# Processing file: job_listings_20161115.json
# Processing file: job_listings_20161116.json
# Processing file: job_listings_20161117.json
# Processed and saved: job_listings_20161103.json
# Processed and saved: job_listings_20161104.json
# Processed and saved: job_listings_20161106.json
# Processed and saved: job_listings_20161107.json
# Processing file: job_listings_20161118.json
# Processed and saved: job_listings_20161108.json
# Processing file: job_listings_20161120.json
# Processing file: job_listings_20161119.json
# Processing file: job_listings_20161121.json
# Processed and saved: job_listings_20161109.json
# Processed and saved: job_listings_20161110.json
# Processing file: job_listings_20161122.json
# Processing file: job_listings_20161123.json
# Processing file: job_listings_20161124.json
# Processing file: job_listings_20161125.json
# Processed and saved: job_listings_20161111.json
# Processed and saved: job_listings_20161112.json
# Processed and saved: job_listings_20161114.json
# Processing file: job_listings_20161126.json
# Processing file: job_listings_20161128.json
# Processing file: job_listings_20161127.json
# Processed and saved: job_listings_20161115.json
# Processed and saved: job_listings_20161116.json
# Processed and saved: job_listings_20161117.json
# Processed and saved: job_listings_20161118.json
# Processing file: job_listings_20161129.json
# Processing file: job_listings_20161130.json
# Processing file: job_listings_20161201.json
# Processing file: job_listings_20161202.json
# Processing file: job_listings_20161203.json
# Processed and saved: job_listings_20161119.json
# Processed and saved: job_listings_20161120.json
# Processed and saved: job_listings_20161121.json
# Processed and saved: job_listings_20161122.json
# Processed and saved: job_listings_20161123.json
# Processed and saved: job_listings_20161124.json
# Processing file: job_listings_20161207.json
# Processing file: job_listings_20161204.json
# Processing file: job_listings_20161205.json
# Processed and saved: job_listings_20161125.json
# Processed and saved: job_listings_20161126.json
# Processing file: job_listings_20161206.json
# Processed and saved: job_listings_20161127.json
# Processed and saved: job_listings_20161128.json
# Processing file: job_listings_20161208.json
# Processing file: job_listings_20161209.json
# Processed and saved: job_listings_20161129.json
# Processing file: job_listings_20161210.json
# Processing file: job_listings_20161211.json
# Processing file: job_listings_20161212.json
# Processing file: job_listings_20161213.json
# Processing file: job_listings_20161214.json
# Processed and saved: job_listings_20161130.json
# Processed and saved: job_listings_20161201.json
# Processed and saved: job_listings_20161202.json
# Processed and saved: job_listings_20161203.json
# Processing file: job_listings_20161215.json
# Processed and saved: job_listings_20161204.json
# Processing file: job_listings_20161216.json
# Processing file: job_listings_20161217.json
# Processed and saved: job_listings_20161205.json
# Processed and saved: job_listings_20161206.json
# Processed and saved: job_listings_20161207.json
# Processed and saved: job_listings_20161208.json
# Processing file: job_listings_20161218.json
# Processing file: job_listings_20161219.json
# Processing file: job_listings_20161220.json
# Processing file: job_listings_20161221.json
# Processed and saved: job_listings_20161209.json
# Processed and saved: job_listings_20161210.json
# Processed and saved: job_listings_20161211.json
# Processing file: job_listings_20161223.json
# Processing file: job_listings_20161222.json
# Processing file: job_listings_20161224.json
# Processing file: job_listings_20161225.json
# Processing file: job_listings_20161226.json
# Processing file: job_listings_20161227.json
# Processing file: job_listings_20161228.json
# Processed and saved: job_listings_20161212.json
# Processed and saved: job_listings_20161213.json
# Processed and saved: job_listings_20161214.json
# Processed and saved: job_listings_20161215.json
# Processed and saved: job_listings_20161216.json
# Processed and saved: job_listings_20161217.json
# Processed and saved: job_listings_20161218.json
# Processing file: job_listings_20161229.json
# Processing file: job_listings_20161230.json
# Processed and saved: job_listings_20161219.json
# Processed and saved: job_listings_20161220.json
# Processed and saved: job_listings_20161221.json
# Processing file: job_listings_20170101.json
# Processing file: job_listings_20170102.json
# Processed and saved: job_listings_20161222.json
# Processing file: job_listings_20170103.json
# Processing file: job_listings_20170104.json
# Processing file: job_listings_20170105.json
# Processed and saved: job_listings_20161223.json
# Processed and saved: job_listings_20161224.json
# Processed and saved: job_listings_20161225.json
# Processed and saved: job_listings_20161226.json
# Processed and saved: job_listings_20161227.json
# Processed and saved: job_listings_20161228.json
# Processing file: job_listings_20170109.json
# Processing file: job_listings_20170106.json
# Processing file: job_listings_20170107.json
# Processing file: job_listings_20170110.json
# Processing file: job_listings_20170111.json
# Processed and saved: job_listings_20161229.json
# Processed and saved: job_listings_20161230.json
# Processing file: job_listings_20170112.json
# Processed and saved: job_listings_20170101.json
# Processing file: job_listings_20170113.json
# Processing file: job_listings_20170114.json
# Processed and saved: job_listings_20170102.json
# Processed and saved: job_listings_20170103.json
# Processing file: job_listings_20170115.json
# Processing file: job_listings_20170116.json
# Processed and saved: job_listings_20170104.json
# Processed and saved: job_listings_20170105.json
# Processed and saved: job_listings_20170106.json
# Processed and saved: job_listings_20170107.json
# Processing file: job_listings_20170117.json
# Processing file: job_listings_20170118.json
# Processed and saved: job_listings_20170109.json
# Processing file: job_listings_20170120.json
# Processing file: job_listings_20170119.json
# Processing file: job_listings_20170121.json
# Processing file: job_listings_20170122.json
# Processed and saved: job_listings_20170110.json
# Processed and saved: job_listings_20170111.json
# Processing file: job_listings_20170123.json
# Processing file: job_listings_20170124.json
# Processed and saved: job_listings_20170112.json
# Processed and saved: job_listings_20170113.json
# Processed and saved: job_listings_20170114.json
# Processed and saved: job_listings_20170115.json
# Processing file: job_listings_20170125.json
# Processing file: job_listings_20170126.json
# Processing file: job_listings_20170128.json
# Processing file: job_listings_20170127.json
# Processed and saved: job_listings_20170116.json
# Processing file: job_listings_20170129.json
# Processed and saved: job_listings_20170117.json
# Processed and saved: job_listings_20170118.json
# Processed and saved: job_listings_20170119.json
# Processing file: job_listings_20170130.json
# Processing file: job_listings_20170131.json
# Processing file: job_listings_20170201.json
# Processed and saved: job_listings_20170120.json
# Processed and saved: job_listings_20170121.json
# Processed and saved: job_listings_20170122.json
# Processing file: job_listings_20170202.json
# Processing file: job_listings_20170204.json
# Processing file: job_listings_20170203.json
# Processed and saved: job_listings_20170123.json
# Processed and saved: job_listings_20170124.json
# Processed and saved: job_listings_20170125.json
# Processing file: job_listings_20170206.json
# Processing file: job_listings_20170205.json
# Processing file: job_listings_20170209.json
# Processing file: job_listings_20170208.json
# Processed and saved: job_listings_20170126.json
# Processing file: job_listings_20170207.json
# Processed and saved: job_listings_20170127.json
# Processed and saved: job_listings_20170128.json
# Processed and saved: job_listings_20170129.json
# Processed and saved: job_listings_20170130.json
# Processed and saved: job_listings_20170131.json
# Processing file: job_listings_20170210.json
# Processed and saved: job_listings_20170201.json
# Processing file: job_listings_20170211.json
# Processing file: job_listings_20170212.json
# Processing file: job_listings_20170213.json
# Processed and saved: job_listings_20170202.json
# Processing file: job_listings_20170214.json
# Processed and saved: job_listings_20170203.json
# Processed and saved: job_listings_20170204.json
# Processed and saved: job_listings_20170205.json
# Processed and saved: job_listings_20170206.json
# Processing file: job_listings_20170216.json
# Processing file: job_listings_20170217.json
# Processing file: job_listings_20170215.json
# Processing file: job_listings_20170218.json
# Processing file: job_listings_20170220.json
# Processing file: job_listings_20170221.json
# Processing file: job_listings_20170222.json
# Processed and saved: job_listings_20170207.json
# Processed and saved: job_listings_20170208.json
# Processed and saved: job_listings_20170209.json
# Processed and saved: job_listings_20170210.json
# Processed and saved: job_listings_20170211.json
# Processing file: job_listings_20170223.json
# Processed and saved: job_listings_20170212.json
# Processed and saved: job_listings_20170213.json
# Processing file: job_listings_20170224.json
# Processing file: job_listings_20170225.json
# Processed and saved: job_listings_20170214.jsonProcessing file: job_listings_20170227.json
# Processing file: job_listings_20170228.json
#
# Processed and saved: job_listings_20170215.json
# Processed and saved: job_listings_20170216.json
# Processed and saved: job_listings_20170217.json
# Processing file: job_listings_20170301.json
# Processing file: job_listings_20170302.json
# Processing file: job_listings_20170303.json
# Processed and saved: job_listings_20170218.json
# Processing file: job_listings_20170304.json
# Processing file: job_listings_20170305.json
# Processed and saved: job_listings_20170220.json
# Processed and saved: job_listings_20170221.json
# Processed and saved: job_listings_20170222.json
# Processing file: job_listings_20170306.json
# Processed and saved: job_listings_20170223.json
# Processing file: job_listings_20170307.json
# Processed and saved: job_listings_20170224.json
# Processing file: job_listings_20170308.json
# Processed and saved: job_listings_20170225.json
# Processing file: job_listings_20170309.json
# Processing file: job_listings_20170310.json
# Processed and saved: job_listings_20170227.json
# Processed and saved: job_listings_20170228.json
# Processed and saved: job_listings_20170301.json
# Processing file: job_listings_20170311.json
# Processing file: job_listings_20170313.json
# Processing file: job_listings_20170314.json
# Processed and saved: job_listings_20170302.json
# Processed and saved: job_listings_20170303.json
# Processed and saved: job_listings_20170304.json
# Processing file: job_listings_20170315.json
# Processing file: job_listings_20170316.json
# Processing file: job_listings_20170317.json
# Processed and saved: job_listings_20170305.json
# Processed and saved: job_listings_20170306.json
# Processing file: job_listings_20170318.json
# Processed and saved: job_listings_20170307.json
# Processed and saved: job_listings_20170308.json
# Processing file: job_listings_20170320.json
# Processing file: job_listings_20170321.json
# Processing file: job_listings_20170327.json
# Processing file: job_listings_20170323.json
# Processing file: job_listings_20170324.json
# Processed and saved: job_listings_20170309.json
# Processed and saved: job_listings_20170310.json
# Processed and saved: job_listings_20170311.json
# Processed and saved: job_listings_20170313.json
# Processed and saved: job_listings_20170314.json
# Processed and saved: job_listings_20170315.json
# Processed and saved: job_listings_20170316.json
# Processing file: job_listings_20170325.json
# Processing file: job_listings_20170328.json
# Processing file: job_listings_20170322.json
# Processed and saved: job_listings_20170317.json
# Processing file: job_listings_20170329.json
# Processed and saved: job_listings_20170318.json
# Processing file: job_listings_20170330.json
# Processed and saved: job_listings_20170320.json
# Processing file: job_listings_20170331.json
# Processed and saved: job_listings_20170321.json
# Processing file: job_listings_20170401.json
# Processing file: job_listings_20170402.json
# Processing file: job_listings_20170403.json
# Processing file: job_listings_20170404.json
# Processing file: job_listings_20170406.json
# Processing file: job_listings_20170405.json
# Processing file: job_listings_20170407.json
# Processing file: job_listings_20170408.json
# Processed and saved: job_listings_20170322.json
# Processed and saved: job_listings_20170323.json
# Processed and saved: job_listings_20170324.json
# Processed and saved: job_listings_20170325.json
# Processed and saved: job_listings_20170327.json
# Processed and saved: job_listings_20170328.json
# Processed and saved: job_listings_20170329.json
# Processed and saved: job_listings_20170330.json
# Processing file: job_listings_20170409.json
# Processing file: job_listings_20170410.json
# Processed and saved: job_listings_20170331.json
# Processed and saved: job_listings_20170401.json
# Processing file: job_listings_20170411.json
# Processing file: job_listings_20170412.json
# Processed and saved: job_listings_20170402.json
# Processed and saved: job_listings_20170403.json
# Processed and saved: job_listings_20170404.json
# Processing file: job_listings_20170414.json
# Processing file: job_listings_20170413.json
# Processing file: job_listings_20170415.json
# Processing file: job_listings_20170416.json
# Processed and saved: job_listings_20170405.json
# Processed and saved: job_listings_20170406.json
# Processed and saved: job_listings_20170407.json
# Processing file: job_listings_20170417.json
# Processing file: job_listings_20170418.json
# Processing file: job_listings_20170419.json
# Processing file: job_listings_20170420.json
# Processing file: job_listings_20170421.json
# Processing file: job_listings_20170422.json
# Processing file: job_listings_20170423.json
# Processed and saved: job_listings_20170408.json
# Processed and saved: job_listings_20170409.json
# Processed and saved: job_listings_20170410.json
# Processed and saved: job_listings_20170411.json
# Processing file: job_listings_20170424.json
# Processing file: job_listings_20170426.json
# Processing file: job_listings_20170425.json
# Processed and saved: job_listings_20170412.json
# Processed and saved: job_listings_20170413.json
# Processed and saved: job_listings_20170414.json
# Processed and saved: job_listings_20170415.json
# Processed and saved: job_listings_20170416.json
# Processed and saved: job_listings_20170417.json
# Processing file: job_listings_20170427.json
# Processing file: job_listings_20170428.json
# Processed and saved: job_listings_20170418.json
# Processing file: job_listings_20170429.json
# Processing file: job_listings_20170430.json
# Processed and saved: job_listings_20170419.json
# Processing file: job_listings_20170501.json
# Processing file: job_listings_20170502.json
# Processing file: job_listings_20170503.json
# Processed and saved: job_listings_20170420.json
# Processed and saved: job_listings_20170421.json
# Processed and saved: job_listings_20170422.json
# Processed and saved: job_listings_20170423.json
# Processed and saved: job_listings_20170424.json
# Processing file: job_listings_20170504.json
# Processed and saved: job_listings_20170425.json
# Processing file: job_listings_20170505.json
# Processed and saved: job_listings_20170426.json
# Processing file: job_listings_20170506.json
# Processing file: job_listings_20170507.json
# Processed and saved: job_listings_20170427.json
# Processing file: job_listings_20170508.json
# Processed and saved: job_listings_20170428.json
# Processed and saved: job_listings_20170429.json
# Processing file: job_listings_20170509.json
# Processing file: job_listings_20170510.json
# Processing file: job_listings_20170511.json
# Processed and saved: job_listings_20170430.json
# Processed and saved: job_listings_20170501.json
# Processed and saved: job_listings_20170502.json
# Processed and saved: job_listings_20170503.json
# Processing file: job_listings_20170513.json
# Processing file: job_listings_20170512.json
# Processed and saved: job_listings_20170504.json
# Processing file: job_listings_20170514.json
# Processed and saved: job_listings_20170505.json
# Processing file: job_listings_20170515.json
# Processing file: job_listings_20170516.json
# Processed and saved: job_listings_20170506.json
# Processed and saved: job_listings_20170507.json
# Processing file: job_listings_20170517.json
# Processing file: job_listings_20170518.json
# Processing file: job_listings_20170519.json
# Processing file: job_listings_20170520.json
# Processed and saved: job_listings_20170508.json
# Processed and saved: job_listings_20170509.json
# Processing file: job_listings_20170521.json
# Processed and saved: job_listings_20170510.json
# Processing file: job_listings_20170522.json
# Processing file: job_listings_20170523.json
# Processed and saved: job_listings_20170511.json
# Processed and saved: job_listings_20170512.json
# Processed and saved: job_listings_20170513.json
# Processed and saved: job_listings_20170514.json
# Processed and saved: job_listings_20170515.json
# Processing file: job_listings_20170525.json
# Processing file: job_listings_20170524.json
# Processed and saved: job_listings_20170516.json
# Processing file: job_listings_20170527.json
# Processing file: job_listings_20170526.json
# Processed and saved: job_listings_20170517.json
# Processed and saved: job_listings_20170518.json
# Processing file: job_listings_20170529.json
# Processing file: job_listings_20170530.json
# Processing file: job_listings_20170601.json
# Processed and saved: job_listings_20170519.json
# Processed and saved: job_listings_20170520.json
# Processing file: job_listings_20170531.json
# Processing file: job_listings_20170602.json
# Processed and saved: job_listings_20170521.json
# Processed and saved: job_listings_20170522.json
# Processed and saved: job_listings_20170523.json
# Processing file: job_listings_20170603.json
# Processed and saved: job_listings_20170524.json
# Processing file: job_listings_20170604.json
# Processing file: job_listings_20170605.json
# Processing file: job_listings_20170606.json
# Processing file: job_listings_20170607.json
# Processed and saved: job_listings_20170525.json
# Processed and saved: job_listings_20170526.json
# Processing file: job_listings_20170608.json
# Processed and saved: job_listings_20170527.json
# Processed and saved: job_listings_20170529.json
# Processing file: job_listings_20170609.json
# Processing file: job_listings_20170610.json
# Processing file: job_listings_20170611.json
# Processed and saved: job_listings_20170530.json
# Processed and saved: job_listings_20170531.json
# Processing file: job_listings_20170612.json
# Processing file: job_listings_20170613.json
# Processing file: job_listings_20170614.json
# Processing file: job_listings_20170616.json
# Processed and saved: job_listings_20170601.json
# Processed and saved: job_listings_20170602.json
# Processed and saved: job_listings_20170603.json
# Processed and saved: job_listings_20170604.json
# Processed and saved: job_listings_20170605.json
# Processed and saved: job_listings_20170606.json
# Processing file: job_listings_20170615.json
# Processed and saved: job_listings_20170607.json
# Processing file: job_listings_20170617.json
# Processing file: job_listings_20170619.json
# Processed and saved: job_listings_20170608.json
# Processed and saved: job_listings_20170609.json
# Processing file: job_listings_20170620.json
# Processed and saved: job_listings_20170610.json
# Processing file: job_listings_20170622.json
# Processing file: job_listings_20170621.json
# Processing file: job_listings_20170623.json
# Processed and saved: job_listings_20170611.json
# Processed and saved: job_listings_20170612.json
# Processing file: job_listings_20170624.json
# Processing file: job_listings_20170626.json
# Processed and saved: job_listings_20170613.json
# Processed and saved: job_listings_20170614.json
# Processed and saved: job_listings_20170615.json
# Processing file: job_listings_20170625.json
# Processing file: job_listings_20170627.json
# Processed and saved: job_listings_20170616.json
# Processed and saved: job_listings_20170617.json
# Processing file: job_listings_20170628.json
# Processing file: job_listings_20170629.json
# Processing file: job_listings_20170630.json
# Processed and saved: job_listings_20170619.json
# ...
# Processing file: job_listings_20240602.json
# Processing file: job_listings_20240531.json
# Processed and saved: job_listings_20240518.json
# Processed and saved: job_listings_20240520.json
# Processed and saved: job_listings_20240521.json
# Processed and saved: job_listings_20240522.json
# Processing file: job_listings_20240530.json
# Processing file: job_listings_20240601.json
# Processed and saved: job_listings_20240523.json
# Processed and saved: job_listings_20240524.json
# Processed and saved: job_listings_20240525.json
# Processing file: job_listings_20240604.jsonProcessing file: job_listings_20240603.json
#
# Processing file: job_listings_20240605.json
# Processing file: job_listings_20240606.json
# Processing file: job_listings_20240607.json
# Processing file: job_listings_20240609.json
# Processing file: job_listings_20240610.json
# Processed and saved: job_listings_20240526.json
# Processed and saved: job_listings_20240527.json
# Processed and saved: job_listings_20240528.json
# Processing file: job_listings_20240611.json
# Processing file: job_listings_20240613.json
# Processing file: job_listings_20240612.json
# Processed and saved: job_listings_20240529.json
# Processed and saved: job_listings_20240530.json
# Processed and saved: job_listings_20240531.json
# Processed and saved: job_listings_20240601.json
# Processed and saved: job_listings_20240602.json
# Processing file: job_listings_20240614.json
# Processed and saved: job_listings_20240603.json
# Processed and saved: job_listings_20240604.json
# Processing file: job_listings_20240615.json
# Processing file: job_listings_20240617.json
# Processing file: job_listings_20240618.json
# Processed and saved: job_listings_20240605.json
# Processing file: job_listings_20240619.json
# Processed and saved: job_listings_20240606.json
# Processed and saved: job_listings_20240607.json
# Processed and saved: job_listings_20240609.json
# Processed and saved: job_listings_20240610.json
# Processed and saved: job_listings_20240611.json
# Processing file: job_listings_20240620.json
# Processing file: job_listings_20240621.json
# Processing file: job_listings_20240624.json
# Processing file: job_listings_20240625.json
# Processed and saved: job_listings_20240612.json
# Processed and saved: job_listings_20240613.json
# Processing file: job_listings_20240626.json
# Processed and saved: job_listings_20240614.json
# Processed and saved: job_listings_20240615.json
# Processing file: job_listings_20240627.json
# Processing file: job_listings_20240628.json
# Processing file: job_listings_20240629.json
# Processing file: job_listings_20240630.json
# Processed and saved: job_listings_20240617.json
# Processed and saved: job_listings_20240618.json
# Processed and saved: job_listings_20240619.json
# Processing file: job_listings_20240701.json
# Processing file: job_listings_20240702.json
# Processed and saved: job_listings_20240620.json
# Processing file: job_listings_20240703.json
# Processing file: job_listings_20240704.json
# Processing file: job_listings_20240706.json
# Processing file: job_listings_20240707.json
# Processing file: job_listings_20240705.json
# Processed and saved: job_listings_20240621.json
# Processed and saved: job_listings_20240624.json
# Processed and saved: job_listings_20240625.json
# Processed and saved: job_listings_20240626.json
# Processed and saved: job_listings_20240627.json
# Processing file: job_listings_20240708.json
# Processed and saved: job_listings_20240628.json
# Processing file: job_listings_20240709.json
# Processing file: job_listings_20240710.json
# Processing file: job_listings_20240711.json
# Processing file: job_listings_20240712.json
# Processed and saved: job_listings_20240629.json
# Processed and saved: job_listings_20240630.json
# Processing file: job_listings_20240713.json
# Processing file: job_listings_20240714.json
# Processing file: job_listings_20240715.json
# Processing file: job_listings_20240717.json
# Processing file: job_listings_20240716.json
# Processed and saved: job_listings_20240701.json
# Processed and saved: job_listings_20240702.json
# Processed and saved: job_listings_20240703.json
# Processed and saved: job_listings_20240704.json
# Processed and saved: job_listings_20240705.json
# Processed and saved: job_listings_20240706.json
# Processed and saved: job_listings_20240707.json
# Processed and saved: job_listings_20240708.json
# Processing file: job_listings_20240718.json
# Processing file: job_listings_20240719.jsonProcessing file: job_listings_20240720.json
#
# Processing file: job_listings_20240722.json
# Processed and saved: job_listings_20240709.json
# Processed and saved: job_listings_20240710.json
# Processed and saved: job_listings_20240711.json
# Processed and saved: job_listings_20240712.json
# Processing file: job_listings_20240723.json
# Processing file: job_listings_20240724.json
# Processed and saved: job_listings_20240713.json
# Processed and saved: job_listings_20240714.json
# Processing file: job_listings_20240725.json
# Processing file: job_listings_20240726.json
# Processing file: job_listings_20240727.json
# Processed and saved: job_listings_20240715.json
# Processed and saved: job_listings_20240716.json
# Processed and saved: job_listings_20240717.json
# Processing file: job_listings_20240728.json
# Processing file: job_listings_20240729.json
# Processed and saved: job_listings_20240718.json
# Processing file: job_listings_20240730.json
# Processing file: job_listings_20240731.json
# Processing file: job_listings_20240801.json
# Processing file: job_listings_20240802.json
# Processing file: job_listings_20240803.json
# Processed and saved: job_listings_20240719.json
# Processed and saved: job_listings_20240720.json
# Processed and saved: job_listings_20240722.json
# Processing file: job_listings_20240804.json
# Processing file: job_listings_20240805.json
# Processing file: job_listings_20240806.json
# Processed and saved: job_listings_20240723.json
# Processed and saved: job_listings_20240724.json
# Processed and saved: job_listings_20240725.json
# Processed and saved: job_listings_20240726.json
# Processing file: job_listings_20240807.json
# Processing file: job_listings_20240810.json
# Processing file: job_listings_20240809.json
# Processed and saved: job_listings_20240727.json
# Processed and saved: job_listings_20240728.json
# Processed and saved: job_listings_20240729.json
# Processed and saved: job_listings_20240730.json
# Processed and saved: job_listings_20240731.json
# Processing file: job_listings_20240808.json
# Processing file: job_listings_20240812.json
# Processing file: job_listings_20240813.json
# Processing file: job_listings_20240814.json
# Processed and saved: job_listings_20240801.json
# Processing file: job_listings_20240815.json
# Processing file: job_listings_20240816.json
# Processed and saved: job_listings_20240802.json
# Processed and saved: job_listings_20240803.json
# Processed and saved: job_listings_20240804.json
# Processing file: job_listings_20240817.json
# Processing file: job_listings_20240819.json
# Processing file: job_listings_20240820.json
# Processing file: job_listings_20240821.json
# Processed and saved: job_listings_20240805.json
# Processed and saved: job_listings_20240806.json
# Processed and saved: job_listings_20240807.json
# Processed and saved: job_listings_20240808.json
# Processed and saved: job_listings_20240809.json
# Processed and saved: job_listings_20240810.json
# Processing file: job_listings_20240822.json
# Processing file: job_listings_20240823.json
# Processed and saved: job_listings_20240812.json
# Processed and saved: job_listings_20240813.json
# Processing file: job_listings_20240825.json
# Processed and saved: job_listings_20240814.json
# Processed and saved: job_listings_20240815.json
# Processing file: job_listings_20240827.json
# Processing file: job_listings_20240826.json
# Processing file: job_listings_20240828.json
# Processing file: job_listings_20240829.json
# Processed and saved: job_listings_20240816.json
# Processing file: job_listings_20240831.json
# Processing file: job_listings_20240830.json
# Processing file: job_listings_20240902.json
# Processed and saved: job_listings_20240817.json
# Processed and saved: job_listings_20240819.json
# Processed and saved: job_listings_20240820.json
# Processed and saved: job_listings_20240821.json
# Processed and saved: job_listings_20240822.json
# Processing file: job_listings_20240903.json
# Processing file: job_listings_20240904.json
# Processing file: job_listings_20240906.json
# Processed and saved: job_listings_20240823.json
# Processing file: job_listings_20240905.json
# Processing file: job_listings_20240909.json
# Processing file: job_listings_20240907.json
# Processing file: job_listings_20240910.json
# Processing file: job_listings_20240912.json
# Processed and saved: job_listings_20240825.json
# Processed and saved: job_listings_20240826.json
# Processed and saved: job_listings_20240827.json
# Processed and saved: job_listings_20240828.json
# Processed and saved: job_listings_20240829.json
# Processed and saved: job_listings_20240830.json
# Processed and saved: job_listings_20240831.json
# Processing file: job_listings_20240911.json
# Processing file: job_listings_20240913.json
# Processed and saved: job_listings_20240902.json
# Processed and saved: job_listings_20240903.json
# Processing file: job_listings_20240914.json
# Processed and saved: job_listings_20240904.jsonProcessing file: job_listings_20240915.json
# Processing file: job_listings_20240916.json
# Processing file: job_listings_20240917.json
# Processing file: job_listings_20240918.json
#
# Processing file: job_listings_20240920.json
# Processing file: job_listings_20240921.json
# Processing file: job_listings_20240919.json
# Processing file: job_listings_20240922.json
# Processed and saved: job_listings_20240905.json
# Processed and saved: job_listings_20240906.json
# Processed and saved: job_listings_20240907.json
# Processed and saved: job_listings_20240909.json
# Processed and saved: job_listings_20240910.json
# Processed and saved: job_listings_20240911.json
# Processed and saved: job_listings_20240912.json
# Processing file: job_listings_20240923.json
# Processing file: job_listings_20240924.json
# Processed and saved: job_listings_20240913.json
# Processed and saved: job_listings_20240914.json
# Processing file: job_listings_20240925.json
# Processing file: job_listings_20240927.json
# Processing file: job_listings_20240926.json
# Processing file: job_listings_20240928.json
# Processing file: job_listings_20240929.json
# Processing file: job_listings_20240930.json
# Processing file: job_listings_20241001.json
# Processing file: job_listings_20241002.json
# Processing file: job_listings_20241003.json
# Processed and saved: job_listings_20240915.json
# Processed and saved: job_listings_20240916.json
# Processed and saved: job_listings_20240917.json
# Processed and saved: job_listings_20240918.json
# Processed and saved: job_listings_20240919.json
# Processed and saved: job_listings_20240920.json
# Processed and saved: job_listings_20240921.json
# Processed and saved: job_listings_20240922.json
# Processed and saved: job_listings_20240923.json
# Processing file: job_listings_20241004.json
# Processed and saved: job_listings_20240924.json
# Processed and saved: job_listings_20240925.json
# Processed and saved: job_listings_20240926.json
# Processing file: job_listings_20241006.json
# Processing file: job_listings_20241007.json
# Processing file: job_listings_20241005.json
# Processing file: job_listings_20241008.json
# Processing file: job_listings_20241009.json
# Processing file: job_listings_20241010.json
# Processed and saved: job_listings_20240927.json
# Processed and saved: job_listings_20240928.json
# Processed and saved: job_listings_20240929.json
# Processed and saved: job_listings_20240930.json
# Processed and saved: job_listings_20241001.json
# Processed and saved: job_listings_20241002.json
# Processed and saved: job_listings_20241003.json
# Processing file: job_listings_20241011.json
# Processing file: job_listings_20241012.json
# Processing file: job_listings_20241013.json
# Processed and saved: job_listings_20241004.json
# Processing file: job_listings_20241014.json
# Processing file: job_listings_20241016.json
# Processing file: job_listings_20241015.json
# Processing file: job_listings_20241018.json
# Processed and saved: job_listings_20241005.json
# Processing file: job_listings_20241017.json
# Processing file: job_listings_20241019.json
# Processed and saved: job_listings_20241006.json
# Processed and saved: job_listings_20241007.json
# Processed and saved: job_listings_20241008.json
# Processing file: job_listings_20241020.json
# Processing file: job_listings_20241021.json
# Processing file: job_listings_20241022.json
# Processed and saved: job_listings_20241009.json
# Processed and saved: job_listings_20241010.json
# Processed and saved: job_listings_20241011.json
# Processed and saved: job_listings_20241012.json
# Processing file: job_listings_20241023.json
# Processed and saved: job_listings_20241013.json
# Processed and saved: job_listings_20241014.json
# Processing file: job_listings_20241024.json
# Processing file: job_listings_20241025.jsonProcessed and saved: job_listings_20241015.json
#
# Processed and saved: job_listings_20241016.json
# Processing file: job_listings_20241026.json
# Processing file: job_listings_20241027.json
# Processing file: job_listings_20241029.json
# Processed and saved: job_listings_20241017.json
# Processing file: job_listings_20241028.json
# Processing file: job_listings_20241031.json
# Processing file: job_listings_20241030.json
# Processing file: job_listings_20241102.json
# Processing file: job_listings_20241101.json
# Processing file: job_listings_20241104.json
# Processed and saved: job_listings_20241018.json
# Processed and saved: job_listings_20241019.json
# Processed and saved: job_listings_20241020.json
# Processed and saved: job_listings_20241021.json
# Processed and saved: job_listings_20241022.json
# Processed and saved: job_listings_20241023.json
# Processed and saved: job_listings_20241024.json
# Processing file: job_listings_20241105.json
# Processed and saved: job_listings_20241025.json
# Processing file: job_listings_20241106.json
# Processing file: job_listings_20241107.json
# Processed and saved: job_listings_20241026.json
# Processed and saved: job_listings_20241027.json
# Processed and saved: job_listings_20241028.json
# Processing file: job_listings_20241108.json
# Processed and saved: job_listings_20241029.json
# Processing file: job_listings_20241109.json
# Processing file: job_listings_20241110.json
# Processing file: job_listings_20241111.json
# Processing file: job_listings_20241112.json
# Processing file: job_listings_20241113.json
# Processed and saved: job_listings_20241030.json
# Processed and saved: job_listings_20241031.json
# Processed and saved: job_listings_20241101.json
# Processed and saved: job_listings_20241102.json
# Processing file: job_listings_20241114.json
# Processed and saved: job_listings_20241104.json
# Processed and saved: job_listings_20241105.json
# Processed and saved: job_listings_20241106.json
# Processing file: job_listings_20241118.json
# Processing file: job_listings_20241115.json
# Processing file: job_listings_20241119.json
# Processed and saved: job_listings_20241107.json
# Processed and saved: job_listings_20241108.json
# Processed and saved: job_listings_20241109.json
# Processing file: job_listings_20241120.json
# Processing file: job_listings_20241121.json
# Processed and saved: job_listings_20241110.json
# Processed and saved: job_listings_20241111.json
# Processed and saved: job_listings_20241112.json
# Processed and saved: job_listings_20241113.json
# Processed and saved: job_listings_20241114.json
# Processed and saved: job_listings_20241115.json
# Skipping file (already processed): job_listings_20241117.json
# Processed and saved: job_listings_20241118.json
# Processed and saved: job_listings_20241119.json
# Processed and saved: job_listings_20241120.json
# Processed and saved: job_listings_20241121.json
# Skipping file (already processed): job_listings_20241122.json
# Skipping file (already processed): job_listings_20241125.json
# Skipping file (already processed): job_listings_20241126.json
# Skipping file (already processed): job_listings_20241127.json
# Skipping file (already processed): job_listings_20241128.json
# Skipping file (already processed): job_listings_20241129.json
